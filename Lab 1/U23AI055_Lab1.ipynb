# %%
from datasets import load_dataset
import re

# %%
dataset = load_dataset("ai4bharat/IndicCorpV2", "indiccorp_v2", streaming=True, split="tel_Telu")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]

# %%
def telugu_sentence_tokenizer(text):
    return re.split(r'(?<=[।!?॥.])\s+', text)

def telugu_word_tokenizer(text):
    url = r'https?://\S+'
    email = r'\b[\w\.-]+@[\w\.-]+\.\w+\b'
    date = r'\b\d{1,2}[/-]\d{1,2}[/-]\d{2,4}\b'
    decimal = r'\b\d+\.\d+\b'
    number = r'\b\d+\b'
    telugu = r'[\u0C00-\u0C7F]+'
    english = r'[a-zA-Z]+'
    punctuation = r'[.,!?;:"(){}\[\]<>|/@#$%^&*_+=~`\'“”‘’₹…-]'
    pattern = f'{url}|{email}|{date}|{decimal}|{number}|{telugu}|{english}|{punctuation}'
    return re.findall(pattern, text)

# %%
for fname in ["original_text.txt", "output_sentence_tokenized.txt", "output_tokenized.txt"]:
    with open(fname, "w", encoding="utf-8") as f:
        pass

N = 2000

for i, example in enumerate(dataset):
    if i >= N:
        break

    text = example['text'].strip()

    with open("original_text.txt", "a", encoding="utf-8") as f_orig:
        f_orig.write(f"--- Example {i+1} ---\n{text}\n\n")

    sentences = telugu_sentence_tokenizer(text)

    with open("output_sentence_tokenized.txt", "a", encoding="utf-8") as f_sent, \
         open("output_tokenized.txt", "a", encoding="utf-8") as f_word:

        f_sent.write(f"--- Example {i+1} ---\n")
        f_word.write(f"--- Example {i+1} ---\n")

        for j, s in enumerate(sentences):
            f_sent.write(f"Sentence {j+1}: {s}\n")

            words = telugu_word_tokenizer(s)

            f_word.write(f"Sentence {j+1}:\n")
            f_word.write(f"Original: {s}\n")
            f_word.write(f"Tokens  : {' '.join(words)}\n\n")

            print(f"\n Sentence {j+1}: {s}")
            print(f" Tokens: {words}")
# Out:
# Streaming output truncated to the last 5000 lines.
#  Sentence 8: అయినప్పటికీ, 1972 లో హోవర్ ఫ్రాస్ట్తో ప్రసిద్ధి చెందిన "ర్యాప్" కనిపెట్టబడింది.
#  Tokens: ['అయినప్పటికీ', ',', '1972', 'లో', 'హోవర్', 'ఫ్రాస్ట్తో', 'ప్రసిద్ధి', 'చెందిన', '"', 'ర్యాప్', '"', 'కనిపెట్టబడింది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: స‌ర‌దాగా రెండు గంట‌ల సినిమా చూసి, రిలాక్స‌యిపోదాం.
#  Tokens: ['స', 'ర', 'దాగా', 'రెండు', 'గంట', 'ల', 'సినిమా', 'చూసి', ',', 'రిలాక్స', 'యిపోదాం', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: అయితే కొందరు మాత్రమే ఆ కలలను నిజం చేసుకోవడంలో సఫలమవుతారు.అలా ప్రతిభతో సక్సెస్ సాధించిన సింగర్లలో మోహనా భోగరాజు ఒకరు.
#  Tokens: ['అయితే', 'కొందరు', 'మాత్రమే', 'ఆ', 'కలలను', 'నిజం', 'చేసుకోవడంలో', 'సఫలమవుతారు', '.', 'అలా', 'ప్రతిభతో', 'సక్సెస్', 'సాధించిన', 'సింగర్లలో', 'మోహనా', 'భోగరాజు', 'ఒకరు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కాగా తెలుగులో టాలీవుడ్ ప్రముఖ దర్శకుడు క్రిష్ జాగర్లమూడి దర్శకత్వం వహించిన “వేదం” చిత్రం ద్వారా తెలుగు సినిమా పరిశ్రమకు హీరోయిన్ గా పరిచయమైన ఢిల్లీ బ్యూటీ “దీక్షాసేత్” గురించి సినీ ప్రేక్షకులకు కొత్తగా పరిచయం చేయాల్సిన అవసరం లేదు.
#  Tokens: ['కాగా', 'తెలుగులో', 'టాలీవుడ్', 'ప్రముఖ', 'దర్శకుడు', 'క్రిష్', 'జాగర్లమూడి', 'దర్శకత్వం', 'వహించిన', '“', 'వేదం', '”', 'చిత్రం', 'ద్వారా', 'తెలుగు', 'సినిమా', 'పరిశ్రమకు', 'హీరోయిన్', 'గా', 'పరిచయమైన', 'ఢిల్లీ', 'బ్యూటీ', '“', 'దీక్షాసేత్', '”', 'గురించి', 'సినీ', 'ప్రేక్షకులకు', 'కొత్తగా', 'పరిచయం', 'చేయాల్సిన', 'అవసరం', 'లేదు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: జనవరి 16 వ తారీఖున దేశంలో కరోనా టీకా పంపిణీ కార్యక్రమం స్టార్ట్ అయింది.మొదట ఆరోగ్య మున్సిపల్ సిబ్బందికి టీకాలు ఇవ్వటం జరిగింది.తర్వాత ఫ్రంట్లైన్ వర్కర్లకు అదే రీతిలో 60 ఏళ్లు పైబడిన వారికి వ్యాక్సిన్ అందించారు.ప్రస్తుతం 18 సంవత్సరాలు పైబడిన వారందరికీ టీకా లు ఇస్తున్నారు.మొదట 10 కోట్ల డోస్ లు ఇవ్వటానికి దేశంలో ఎనభై నాలుగు రోజులు పడ్డాయి.అయితే ఆ తర్వాత కేంద్రం వ్యాక్సినేషన్ విషయంలో కొత్త పాలసీ విధానం తీసుకోవడంతో 40 నుంచి 50 కోట్ల డోస్ లకి 20 రోజులు మాత్రమే పడ్డాయి.
#  Tokens: ['జనవరి', '16', 'వ', 'తారీఖున', 'దేశంలో', 'కరోనా', 'టీకా', 'పంపిణీ', 'కార్యక్రమం', 'స్టార్ట్', 'అయింది', '.', 'మొదట', 'ఆరోగ్య', 'మున్సిపల్', 'సిబ్బందికి', 'టీకాలు', 'ఇవ్వటం', 'జరిగింది', '.', 'తర్వాత', 'ఫ్రంట్లైన్', 'వర్కర్లకు', 'అదే', 'రీతిలో', '60', 'ఏళ్లు', 'పైబడిన', 'వారికి', 'వ్యాక్సిన్', 'అందించారు', '.', 'ప్రస్తుతం', '18', 'సంవత్సరాలు', 'పైబడిన', 'వారందరికీ', 'టీకా', 'లు', 'ఇస్తున్నారు', '.', 'మొదట', '10', 'కోట్ల', 'డోస్', 'లు', 'ఇవ్వటానికి', 'దేశంలో', 'ఎనభై', 'నాలుగు', 'రోజులు', 'పడ్డాయి', '.', 'అయితే', 'ఆ', 'తర్వాత', 'కేంద్రం', 'వ్యాక్సినేషన్', 'విషయంలో', 'కొత్త', 'పాలసీ', 'విధానం', 'తీసుకోవడంతో', '40', 'నుంచి', '50', 'కోట్ల', 'డోస్', 'లకి', '20', 'రోజులు', 'మాత్రమే', 'పడ్డాయి', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: పెద్దవూర, ఏప్రిల్ 30: నల్లగొండ జిల్లా పెద్దవూర పోలీస్ స్టేషన్ వద్ద మంగళవారం పోలీసులు వాహనాల తనిఖీలు నిర్వహిస్తుండగా 64లక్షల రూపాయలు నగదును పట్టుకున్నారు.
#  Tokens: ['పెద్దవూర', ',', 'ఏప్రిల్', '30', ':', 'నల్లగొండ', 'జిల్లా', 'పెద్దవూర', 'పోలీస్', 'స్టేషన్', 'వద్ద', 'మంగళవారం', 'పోలీసులు', 'వాహనాల', 'తనిఖీలు', 'నిర్వహిస్తుండగా', 'లక్షల', 'రూపాయలు', 'నగదును', 'పట్టుకున్నారు', '.']
#
#  Sentence 2: పోలీసుల వివరాల ప్రకారం..
#  Tokens: ['పోలీసుల', 'వివరాల', 'ప్రకారం', '.', '.']
#
#  Sentence 3: దేవరకొండకు చెందిన కులిజాల పూర్ణయ్య దేవరకొండ నుండి మిర్యాలగూడకు ఏపీ 24ఏయూ 6606 కారులో నగదుతో వెళ్తుండగా పట్టుబడినట్లు తెలిపారు.
#  Tokens: ['దేవరకొండకు', 'చెందిన', 'కులిజాల', 'పూర్ణయ్య', 'దేవరకొండ', 'నుండి', 'మిర్యాలగూడకు', 'ఏపీ', 'ఏయూ', '6606', 'కారులో', 'నగదుతో', 'వెళ్తుండగా', 'పట్టుబడినట్లు', 'తెలిపారు', '.']
#
#  Sentence 4: ఈ నగదుకు ఎలాంటి ఆధారాలు ఇవలేదని ఎస్‌ఐ మోహన్‌బాబు తెలిపారు.
#  Tokens: ['ఈ', 'నగదుకు', 'ఎలాంటి', 'ఆధారాలు', 'ఇవలేదని', 'ఎస్', 'ఐ', 'మోహన్', 'బాబు', 'తెలిపారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కొలువుల కొట్లాట సభకు ఒక్కరోజు ముందు జరిగిన ఈ ఆత్మహత్య చరిత్ర గతిని మరోసారి మలుపు తిప్పుబోతుందా?
#  Tokens: ['కొలువుల', 'కొట్లాట', 'సభకు', 'ఒక్కరోజు', 'ముందు', 'జరిగిన', 'ఈ', 'ఆత్మహత్య', 'చరిత్ర', 'గతిని', 'మరోసారి', 'మలుపు', 'తిప్పుబోతుందా', '?']
#
#  Sentence 2: నీళ్లు, నిధులు, నియామకాలు అంటూ ఉద్యమించి కోరి కొట్లాడి తెచ్చుకున్న తెలంగాణలో తమను గాలికొదిలేశారంటూ జేఏసీ అండతో నిరుద్యోగులు కదంతొక్కుతున్న ఈ సమయంలో ఈ ఆత్మహత్య జరగడంతో ఇలాంటి ప్రశ్నే ఉదయిస్తుంది.
#  Tokens: ['నీళ్లు', ',', 'నిధులు', ',', 'నియామకాలు', 'అంటూ', 'ఉద్యమించి', 'కోరి', 'కొట్లాడి', 'తెచ్చుకున్న', 'తెలంగాణలో', 'తమను', 'గాలికొదిలేశారంటూ', 'జేఏసీ', 'అండతో', 'నిరుద్యోగులు', 'కదంతొక్కుతున్న', 'ఈ', 'సమయంలో', 'ఈ', 'ఆత్మహత్య', 'జరగడంతో', 'ఇలాంటి', 'ప్రశ్నే', 'ఉదయిస్తుంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: సరిలేరు నీకెవ్వరు చిత్రంతో అటు ఫ్యామిలీ ఆడియన్స్ తో పాటు, మాస్ ప్రేక్షకులని కూడా మెప్పించేలా అనిల్ రావిపూడి జాగ్రత్తలు తీసుకుంటున్నాడు.
#  Tokens: ['సరిలేరు', 'నీకెవ్వరు', 'చిత్రంతో', 'అటు', 'ఫ్యామిలీ', 'ఆడియన్స్', 'తో', 'పాటు', ',', 'మాస్', 'ప్రేక్షకులని', 'కూడా', 'మెప్పించేలా', 'అనిల్', 'రావిపూడి', 'జాగ్రత్తలు', 'తీసుకుంటున్నాడు', '.']
#
#  Sentence 2: ఈ చిత్రంలో మహేష్ ఆర్మీ మేజర్ గా నటిస్తున్న సంగతి తెలిసిందే.
#  Tokens: ['ఈ', 'చిత్రంలో', 'మహేష్', 'ఆర్మీ', 'మేజర్', 'గా', 'నటిస్తున్న', 'సంగతి', 'తెలిసిందే', '.']
#
#  Sentence 3: దాదాపు 13 ఏళ్ల తర్వాత విజయశాంతి వెండితెరపై రీఎంట్రీ ఇస్తోంది.
#  Tokens: ['దాదాపు', '13', 'ఏళ్ల', 'తర్వాత', 'విజయశాంతి', 'వెండితెరపై', 'రీఎంట్రీ', 'ఇస్తోంది', '.']
#
#  Sentence 4: మహేష్ సరసన ఈ చిత్రం రష్మిక హీరోయిన్ గా నటిస్తుండగా..
#  Tokens: ['మహేష్', 'సరసన', 'ఈ', 'చిత్రం', 'రష్మిక', 'హీరోయిన్', 'గా', 'నటిస్తుండగా', '.', '.']
#
#  Sentence 5: రాజేంద్ర ప్రసాద్, సంగీత, ప్రకాష్ రాజ్ కీలక పాత్రల్లో నటిస్తున్నారు.
#  Tokens: ['రాజేంద్ర', 'ప్రసాద్', ',', 'సంగీత', ',', 'ప్రకాష్', 'రాజ్', 'కీలక', 'పాత్రల్లో', 'నటిస్తున్నారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: సిద్దిపేట: టీఆర్ఎస్ అభ్యర్థులకు పలుచోట్ల చుక్కెదురవుతోంది.
#  Tokens: ['సిద్దిపేట', ':', 'టీఆర్ఎస్', 'అభ్యర్థులకు', 'పలుచోట్ల', 'చుక్కెదురవుతోంది', '.']
#
#  Sentence 2: ప్రచారం కోసం వెళ్తున్న అభ్యర్థులను స్థానికులు పలుచోట్ల అడ్డుకుంటున్నారు.
#  Tokens: ['ప్రచారం', 'కోసం', 'వెళ్తున్న', 'అభ్యర్థులను', 'స్థానికులు', 'పలుచోట్ల', 'అడ్డుకుంటున్నారు', '.']
#
#  Sentence 3: ఈటెల రాజేందర్, రేఖా నాయక్, బొడిగె శోభ, శంకర్ నాయక్, రాజేందర్ రెడ్డిలని వారి వారి నియోజకవర్గాల్లో ప్రజలు అడ్డుకున్నారు.
#  Tokens: ['ఈటెల', 'రాజేందర్', ',', 'రేఖా', 'నాయక్', ',', 'బొడిగె', 'శోభ', ',', 'శంకర్', 'నాయక్', ',', 'రాజేందర్', 'రెడ్డిలని', 'వారి', 'వారి', 'నియోజకవర్గాల్లో', 'ప్రజలు', 'అడ్డుకున్నారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ప్రతిభతో పాటు అదృష్టం ఉంటేనే రాణిస్తారు
#  Tokens: ['ప్రతిభతో', 'పాటు', 'అదృష్టం', 'ఉంటేనే', 'రాణిస్తారు']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తప్పు ని తప్పు అనడం తప్పు అయితే, ఆ తప్పు ఎన్ని లక్షల సార్లు అయినా చేయవచ్చు ?
#  Tokens: ['తప్పు', 'ని', 'తప్పు', 'అనడం', 'తప్పు', 'అయితే', ',', 'ఆ', 'తప్పు', 'ఎన్ని', 'లక్షల', 'సార్లు', 'అయినా', 'చేయవచ్చు', '?']
#
#  Sentence 2: నోరు మూసుకునే కన్నా, చావడం మిన్న ?
#  Tokens: ['నోరు', 'మూసుకునే', 'కన్నా', ',', 'చావడం', 'మిన్న', '?']
#
#  Sentence 3: అంటున్నారు PVP (పొట్లూరి వీర ప్రసాద్).
#  Tokens: ['అంటున్నారు', 'PVP', '(', 'పొట్లూరి', 'వీర', 'ప్రసాద్', ')', '.']
#
#  Sentence 4: దీనికి కారణం ఉందండి..
#  Tokens: ['దీనికి', 'కారణం', 'ఉందండి', '.', '.']
#
#  Sentence 5: వైసీపీ నేత పొట్లూరి వరప్రసాద్‌కు బంజారాహిల్స్‌ పోలీసులు నోటీసులు జారీ చేసిన సంగతి తెలిసిందే.
#  Tokens: ['వైసీపీ', 'నేత', 'పొట్లూరి', 'వరప్రసాద్', 'కు', 'బంజారాహిల్స్', 'పోలీసులు', 'నోటీసులు', 'జారీ', 'చేసిన', 'సంగతి', 'తెలిసిందే', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఈ వేసవి మూసివేయబడింది ఫ్యాషన్ ఈత దుస్తుల తిరిగి
#  Tokens: ['ఈ', 'వేసవి', 'మూసివేయబడింది', 'ఫ్యాషన్', 'ఈత', 'దుస్తుల', 'తిరిగి']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: భూమి వినియోగం.
#  Tokens: ['భూమి', 'వినియోగం', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఐబీఎంతో చేతులు కలిపిన తెలంగాణ ప్రభుత్వం
#  Tokens: ['ఐబీఎంతో', 'చేతులు', 'కలిపిన', 'తెలంగాణ', 'ప్రభుత్వం']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: విశాఖపట్నంలో జరిగిన బీజేపీ కోర్ కమిటీ సమావేశంలో ఆ పార్టీ కీలక తీర్మానాలు చేసింది.
#  Tokens: ['విశాఖపట్నంలో', 'జరిగిన', 'బీజేపీ', 'కోర్', 'కమిటీ', 'సమావేశంలో', 'ఆ', 'పార్టీ', 'కీలక', 'తీర్మానాలు', 'చేసింది', '.']
#
#  Sentence 2: ప్రస్తుతం రాష్ట్రంలో నెలకొన్న రాజకీయ పరిస్థితులు, దేవాలయాలపై దాడులు, డీజీపీ గౌతమ్ సవాంగ్ ఆరోపణలు, తిరుపతి ఉపఎన్నికలు, రాష్ట్రంలో పార్టీ బలోపేతంతో పాటు పలు కీలక అంశాలపై చర్చించిన కీలక నిర్ణయాలు తీసుకున్నారు బీజేపీ నేతలు.
#  Tokens: ['ప్రస్తుతం', 'రాష్ట్రంలో', 'నెలకొన్న', 'రాజకీయ', 'పరిస్థితులు', ',', 'దేవాలయాలపై', 'దాడులు', ',', 'డీజీపీ', 'గౌతమ్', 'సవాంగ్', 'ఆరోపణలు', ',', 'తిరుపతి', 'ఉపఎన్నికలు', ',', 'రాష్ట్రంలో', 'పార్టీ', 'బలోపేతంతో', 'పాటు', 'పలు', 'కీలక', 'అంశాలపై', 'చర్చించిన', 'కీలక', 'నిర్ణయాలు', 'తీసుకున్నారు', 'బీజేపీ', 'నేతలు', '.']
#
#  Sentence 3: ముఖ్యంగా దేవాలయాల్లో చోటు చేసుకుంటన్న ఘటనలపై గట్టిగా పోరాడాలని డిసైడ్ అయింది.
#  Tokens: ['ముఖ్యంగా', 'దేవాలయాల్లో', 'చోటు', 'చేసుకుంటన్న', 'ఘటనలపై', 'గట్టిగా', 'పోరాడాలని', 'డిసైడ్', 'అయింది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: అదనంగా కొన్ని కొత్త ఫీచర్లను..
#  Tokens: ['అదనంగా', 'కొన్ని', 'కొత్త', 'ఫీచర్లను', '.', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తాళికట్టాడు.
#  Tokens: ['తాళికట్టాడు', '.']
#
#  Sentence 2: కలకాలం తోడుంటానని వాగ్దానం చేశాడు.
#  Tokens: ['కలకాలం', 'తోడుంటానని', 'వాగ్దానం', 'చేశాడు', '.']
#
#  Sentence 3: భార్యతో నూరేళ్లు అన్యోన్యంగా జీవించాల్సిన వాడు అనమానం పెంచుకున్నాడు.
#  Tokens: ['భార్యతో', 'నూరేళ్లు', 'అన్యోన్యంగా', 'జీవించాల్సిన', 'వాడు', 'అనమానం', 'పెంచుకున్నాడు', '.']
#
#  Sentence 4: ఆ తరువాత అత్యంత అమానవీయంగా వ్యవహరించాడు.
#  Tokens: ['ఆ', 'తరువాత', 'అత్యంత', 'అమానవీయంగా', 'వ్యవహరించాడు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: సహాయ కార్యక్రమాలను కోసం పర్ఫెక్ట్ రంగు బ్లష్
#  Tokens: ['సహాయ', 'కార్యక్రమాలను', 'కోసం', 'పర్ఫెక్ట్', 'రంగు', 'బ్లష్']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: భరత్ అనే నేను..
#  Tokens: ['భరత్', 'అనే', 'నేను', '.', '.']
#
#  Sentence 2: టీడీపీకి కష్టమే
#  Tokens: ['టీడీపీకి', 'కష్టమే']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: అసెంబ్లీ నిర్వహణ తదితర అంశాలపై చీఫ్ సెక్రటరీ ఎల్వీ సుబ్రమణ్యంతో శాసనసభ అధికారులు సుదీర్ఘంగా చర్చించినట్లు తెలుస్తోంది.
#  Tokens: ['అసెంబ్లీ', 'నిర్వహణ', 'తదితర', 'అంశాలపై', 'చీఫ్', 'సెక్రటరీ', 'ఎల్వీ', 'సుబ్రమణ్యంతో', 'శాసనసభ', 'అధికారులు', 'సుదీర్ఘంగా', 'చర్చించినట్లు', 'తెలుస్తోంది', '.']
#
#  Sentence 2: జూన్ 11, 12 తేదీల్లో అసెంబ్లీ ప్రత్యేక సమావేశాలు జరిగే ఛాన్స్ కనిపిస్తోంది.
#  Tokens: ['జూన్', '11', ',', '12', 'తేదీల్లో', 'అసెంబ్లీ', 'ప్రత్యేక', 'సమావేశాలు', 'జరిగే', 'ఛాన్స్', 'కనిపిస్తోంది', '.']
#
#  Sentence 3: జూన్‌ చివరలో బడ్జెట్‌ సమావేశాలు నిర్వహించే అవకాశముంది.
#  Tokens: ['జూన్', 'చివరలో', 'బడ్జెట్', 'సమావేశాలు', 'నిర్వహించే', 'అవకాశముంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: సినిమా ఇండస్ట్రీలో చాలా కాలంగా కాస్టింగ్ కౌచ్ భాగోతంపై హీరోయిన్స్, ఇతర నటీమణులు తమ గొంతుక వినిపిస్తున్నారు.హాలీవుడ్ లో స్టార్ అయిన మీటూ ఉద్యమం అలా టాలీవుడ్ ఇండస్ట్రీ వరకు వచ్చేసింది.నటి శ్రీరెడ్డి ఈ వ్యవహారాన్ని కొంత కాలం సీరియస్ గా...
#  Tokens: ['సినిమా', 'ఇండస్ట్రీలో', 'చాలా', 'కాలంగా', 'కాస్టింగ్', 'కౌచ్', 'భాగోతంపై', 'హీరోయిన్స్', ',', 'ఇతర', 'నటీమణులు', 'తమ', 'గొంతుక', 'వినిపిస్తున్నారు', '.', 'హాలీవుడ్', 'లో', 'స్టార్', 'అయిన', 'మీటూ', 'ఉద్యమం', 'అలా', 'టాలీవుడ్', 'ఇండస్ట్రీ', 'వరకు', 'వచ్చేసింది', '.', 'నటి', 'శ్రీరెడ్డి', 'ఈ', 'వ్యవహారాన్ని', 'కొంత', 'కాలం', 'సీరియస్', 'గా', '.', '.', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: మెగా డాటర్ నిహారిక పెళ్లి వేడుకకు రంగం సిద్ధమైంది.
#  Tokens: ['మెగా', 'డాటర్', 'నిహారిక', 'పెళ్లి', 'వేడుకకు', 'రంగం', 'సిద్ధమైంది', '.']
#
#  Sentence 2: కొణిదెల వారింట పెళ్లి బాజాలు మోగడానికి సర్వం సన్నద్ధమైంది.
#  Tokens: ['కొణిదెల', 'వారింట', 'పెళ్లి', 'బాజాలు', 'మోగడానికి', 'సర్వం', 'సన్నద్ధమైంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఏపీకి కాబోయే సీఎం పవన్ కళ్యాణ్… సోము వీర్రాజు
#  Tokens: ['ఏపీకి', 'కాబోయే', 'సీఎం', 'పవన్', 'కళ్యాణ్', '…', 'సోము', 'వీర్రాజు']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: మోనాల్ సేవ్, కుమార్ సాయి ఎలిమినేషన్
#  Tokens: ['మోనాల్', 'సేవ్', ',', 'కుమార్', 'సాయి', 'ఎలిమినేషన్']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: రేపు విడుదల కానున్న నితిన్ చల్ మోహనరంగా గురించి అతని ఫాన్స్ మాత్రమే కాదు పవన్ కళ్యాణ్ అభిమానులు కూడా ఆసక్తిగా ఎదురు చూస్తున్నారు.
#  Tokens: ['రేపు', 'విడుదల', 'కానున్న', 'నితిన్', 'చల్', 'మోహనరంగా', 'గురించి', 'అతని', 'ఫాన్స్', 'మాత్రమే', 'కాదు', 'పవన్', 'కళ్యాణ్', 'అభిమానులు', 'కూడా', 'ఆసక్తిగా', 'ఎదురు', 'చూస్తున్నారు', '.']
#
#  Sentence 2: పవర్ స్టార్ నటించకపోయినా ఆయన బ్యానర్ మీద నిర్మించిన సినిమా కాబట్టి వాళ్ళకు దీని మీద గట్టి హోప్స్ ఉన్నాయి.
#  Tokens: ['పవర్', 'స్టార్', 'నటించకపోయినా', 'ఆయన', 'బ్యానర్', 'మీద', 'నిర్మించిన', 'సినిమా', 'కాబట్టి', 'వాళ్ళకు', 'దీని', 'మీద', 'గట్టి', 'హోప్స్', 'ఉన్నాయి', '.']
#
#  Sentence 3: పైగా త్రివిక్రమ్ సహ నిర్మాతగా మారడంతో పాటు కథను అందించాడన్న వార్త షూటింగ్ మొదలుకాక ముందే దీని మీద ఆసక్తిని పెంచింది.
#  Tokens: ['పైగా', 'త్రివిక్రమ్', 'సహ', 'నిర్మాతగా', 'మారడంతో', 'పాటు', 'కథను', 'అందించాడన్న', 'వార్త', 'షూటింగ్', 'మొదలుకాక', 'ముందే', 'దీని', 'మీద', 'ఆసక్తిని', 'పెంచింది', '.']
#
#  Sentence 4: కాని పవన్ కళ్యాణ్ ఎందుకు ప్రొడక్షన్ లో జాయిన్ అయ్యాడు అనే దాని గురించే కొన్ని అనుమానాలు అలాగే మిగిలిపోయాయి.
#  Tokens: ['కాని', 'పవన్', 'కళ్యాణ్', 'ఎందుకు', 'ప్రొడక్షన్', 'లో', 'జాయిన్', 'అయ్యాడు', 'అనే', 'దాని', 'గురించే', 'కొన్ని', 'అనుమానాలు', 'అలాగే', 'మిగిలిపోయాయి', '.']
#
#  Sentence 5: వాటికి నితిన్ ఒక ఇంటర్వ్యూలో క్లారిటీ ఇచ్చేసాడు.
#  Tokens: ['వాటికి', 'నితిన్', 'ఒక', 'ఇంటర్వ్యూలో', 'క్లారిటీ', 'ఇచ్చేసాడు', '.']
#
#  Sentence 6: పవన్ ఎందుకు నిర్మాతగా తనతో తీయడానికి సిద్ధపడ్డాడో కారణం వివరించాడు.
#  Tokens: ['పవన్', 'ఎందుకు', 'నిర్మాతగా', 'తనతో', 'తీయడానికి', 'సిద్ధపడ్డాడో', 'కారణం', 'వివరించాడు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: దాసరి, అక్కినేని అక్కినేని కాంబినేషన్ అంటేనే అప్పట్లో యమ క్రేజ్…ఈ కాంబోలో వచ్చిన నాలుగవ చిత్రమే ఏడంత స్తుల మేడ..
#  Tokens: ['దాసరి', ',', 'అక్కినేని', 'అక్కినేని', 'కాంబినేషన్', 'అంటేనే', 'అప్పట్లో', 'యమ', 'క్రేజ్', '…', 'ఈ', 'కాంబోలో', 'వచ్చిన', 'నాలుగవ', 'చిత్రమే', 'ఏడంత', 'స్తుల', 'మేడ', '.', '.']
#
#  Sentence 2: సంక్రాంతి సీజన్ లో వచ్చి సూపర్ హిట్ సాధించింది.
#  Tokens: ['సంక్రాంతి', 'సీజన్', 'లో', 'వచ్చి', 'సూపర్', 'హిట్', 'సాధించింది', '.']
#
#  Sentence 3: సుజాత, జయసుధ పోటీపడి నటించిన ఈ చిత్రానికి మహిళా ప్రేక్షకులు బ్రహ్మరథం పట్టారు..కొన్ని ప్రత్యేక షోలు ఆడవారి కోసమే వేశారు అంటేఈ చిత్రానికి వున్న డిమాండ్ ఏమిటో అర్థం అవుతుంది…
#  Tokens: ['సుజాత', ',', 'జయసుధ', 'పోటీపడి', 'నటించిన', 'ఈ', 'చిత్రానికి', 'మహిళా', 'ప్రేక్షకులు', 'బ్రహ్మరథం', 'పట్టారు', '.', '.', 'కొన్ని', 'ప్రత్యేక', 'షోలు', 'ఆడవారి', 'కోసమే', 'వేశారు', 'అంటేఈ', 'చిత్రానికి', 'వున్న', 'డిమాండ్', 'ఏమిటో', 'అర్థం', 'అవుతుంది', '…']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: పాకిస్థాన్ టీ20 కెప్టెన్‌గా ఇటీవల ఎంపికైన బాబర్ అజామ్‌కి మొదట్లోనే పాకిస్థాన్ క్రికెట్ బోర్డు (పీసీబీ) షాకిచ్చింది.
#  Tokens: ['పాకిస్థాన్', 'టీ', '20', 'కెప్టెన్', 'గా', 'ఇటీవల', 'ఎంపికైన', 'బాబర్', 'అజామ్', 'కి', 'మొదట్లోనే', 'పాకిస్థాన్', 'క్రికెట్', 'బోర్డు', '(', 'పీసీబీ', ')', 'షాకిచ్చింది', '.']
#
#  Sentence 2: ఆస్ట్రేలియాతో నవంబరు 3 నుంచి ప్రారంభంకానున్న మూడు టీ20 సిరీస్‌కి మహ్మద్ హఫీజ్, షోయబ్ మాలిక్‌లను ఎంపిక చేయాలని బాబర్ సూచించగా..
#  Tokens: ['ఆస్ట్రేలియాతో', 'నవంబరు', '3', 'నుంచి', 'ప్రారంభంకానున్న', 'మూడు', 'టీ', '20', 'సిరీస్', 'కి', 'మహ్మద్', 'హఫీజ్', ',', 'షోయబ్', 'మాలిక్', 'లను', 'ఎంపిక', 'చేయాలని', 'బాబర్', 'సూచించగా', '.', '.']
#
#  Sentence 3: పీసీబీ కుదరదని తేల్చి చెప్పేసిందట.
#  Tokens: ['పీసీబీ', 'కుదరదని', 'తేల్చి', 'చెప్పేసిందట', '.']
#
#  Sentence 4: శ్రీలంకతో ఇటీవల ముగిసిన మూడు టీ20ల సిరీస్‌ని పాకిస్థాన్ 0-3తో చేజార్చుకున్న నేపథ్యంలో..
#  Tokens: ['శ్రీలంకతో', 'ఇటీవల', 'ముగిసిన', 'మూడు', 'టీ', 'ల', 'సిరీస్', 'ని', 'పాకిస్థాన్', '0', '-', 'తో', 'చేజార్చుకున్న', 'నేపథ్యంలో', '.', '.']
#
#  Sentence 5: కెప్టెన్ సర్ఫరాజ్ అహ్మద్‌పై వేటు వేసిన పీసీబీ..
#  Tokens: ['కెప్టెన్', 'సర్ఫరాజ్', 'అహ్మద్', 'పై', 'వేటు', 'వేసిన', 'పీసీబీ', '.', '.']
#
#  Sentence 6: టీ20 పగ్గాల్ని బాబర్ అజామ్‌కి అప్పగించిన విషయం తెలిసిందే.
#  Tokens: ['టీ', '20', 'పగ్గాల్ని', 'బాబర్', 'అజామ్', 'కి', 'అప్పగించిన', 'విషయం', 'తెలిసిందే', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ప్రముఖ బ్రాండ్‌లకు ముచ్చెమటలు
#  Tokens: ['ప్రముఖ', 'బ్రాండ్', 'లకు', 'ముచ్చెమటలు']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఇదిలావుంటే తాము అభివృద్ధి చేస్తున్న కరోనా వ్యాక్సిన్ కు ప్రపంచ ఆరోగ్య సంస్థ మద్దతు ఉందని..
#  Tokens: ['ఇదిలావుంటే', 'తాము', 'అభివృద్ధి', 'చేస్తున్న', 'కరోనా', 'వ్యాక్సిన్', 'కు', 'ప్రపంచ', 'ఆరోగ్య', 'సంస్థ', 'మద్దతు', 'ఉందని', '.', '.']
#
#  Sentence 2: చైనా తన నివేదికలో పేర్కొంది.
#  Tokens: ['చైనా', 'తన', 'నివేదికలో', 'పేర్కొంది', '.']
#
#  Sentence 3: వ్యాక్సిన్ విషయంలో జూన్‌లో డబ్ల్యూహెచ్‌ఓకు సమాచారం ఇచ్చినట్లు చైనా జాతీయ ఆరోగ్య కమిషన్ అధికారి జెంగ్ జాంగ్‌వే రాయిటర్స్‌కు తెలిపారు.
#  Tokens: ['వ్యాక్సిన్', 'విషయంలో', 'జూన్', 'లో', 'డబ్ల్యూహెచ్', 'ఓకు', 'సమాచారం', 'ఇచ్చినట్లు', 'చైనా', 'జాతీయ', 'ఆరోగ్య', 'కమిషన్', 'అధికారి', 'జెంగ్', 'జాంగ్', 'వే', 'రాయిటర్స్', 'కు', 'తెలిపారు', '.']
#
#  Sentence 4: కాగా ప్రస్తుత అత్యవసర పరిస్థితుల్లో దేశాలు తమ అధికార పరిధిలో వైద్య ఉత్పత్తుల వాడకాన్ని ఆమోదించవచ్చని డబ్ల్యూహెచ్‌ఓ చీఫ్ సైంటిస్ట్ సౌమ్య స్వామినాథన్ అన్నారు, అయితే ఇది తాత్కాలిక పరిష్కారం  మాత్రమే అని అన్నారు.
#  Tokens: ['కాగా', 'ప్రస్తుత', 'అత్యవసర', 'పరిస్థితుల్లో', 'దేశాలు', 'తమ', 'అధికార', 'పరిధిలో', 'వైద్య', 'ఉత్పత్తుల', 'వాడకాన్ని', 'ఆమోదించవచ్చని', 'డబ్ల్యూహెచ్', 'ఓ', 'చీఫ్', 'సైంటిస్ట్', 'సౌమ్య', 'స్వామినాథన్', 'అన్నారు', ',', 'అయితే', 'ఇది', 'తాత్కాలిక', 'పరిష్కారం', 'మాత్రమే', 'అని', 'అన్నారు', '.']
#
#  Sentence 5: దీన్ని ఉపయోగించుకొని చైనా ఎవరికీ  తెలియకుండా మూడో దశ ట్రయల్స్ లో ఉన్న వ్యాక్సిన్ ను రోగులకు ఇస్తుందని నిపుణులు అంటున్నారు.
#  Tokens: ['దీన్ని', 'ఉపయోగించుకొని', 'చైనా', 'ఎవరికీ', 'తెలియకుండా', 'మూడో', 'దశ', 'ట్రయల్స్', 'లో', 'ఉన్న', 'వ్యాక్సిన్', 'ను', 'రోగులకు', 'ఇస్తుందని', 'నిపుణులు', 'అంటున్నారు', '.']
#
#  Sentence 6: క్యాన్‌సీనో సంస్థ రూపొందించిన టీకాను మిలిటరీ సిబ్బందికి ఇచ్చేందుకు చైనా ప్రభుత్వం జూన్‌లోనే అనుమతించింది.
#  Tokens: ['క్యాన్', 'సీనో', 'సంస్థ', 'రూపొందించిన', 'టీకాను', 'మిలిటరీ', 'సిబ్బందికి', 'ఇచ్చేందుకు', 'చైనా', 'ప్రభుత్వం', 'జూన్', 'లోనే', 'అనుమతించింది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: గ్రేటర్ ఎన్నికల్లో ప్రచార పర్వం పీక్‌కి చేరింది.
#  Tokens: ['గ్రేటర్', 'ఎన్నికల్లో', 'ప్రచార', 'పర్వం', 'పీక్', 'కి', 'చేరింది', '.']
#
#  Sentence 2: బీజేపీ- టీఆర్ఎస్ నేతల మధ్య మాటల యుద్ధం తీవ్రస్థాయికి చేరింది.
#  Tokens: ['బీజేపీ', '-', 'టీఆర్ఎస్', 'నేతల', 'మధ్య', 'మాటల', 'యుద్ధం', 'తీవ్రస్థాయికి', 'చేరింది', '.']
#
#  Sentence 3: ఎల్బీ స్టేడియంలో జరిగిన సభలో కేసీఆర్ విపక్షాలపై విరుచుకుపడ్డారు.
#  Tokens: ['ఎల్బీ', 'స్టేడియంలో', 'జరిగిన', 'సభలో', 'కేసీఆర్', 'విపక్షాలపై', 'విరుచుకుపడ్డారు', '.']
#
#  Sentence 4: దీనిపై కౌంటర్లు వస్తున్నాయి.
#  Tokens: ['దీనిపై', 'కౌంటర్లు', 'వస్తున్నాయి', '.']
#
#  Sentence 5: ఫైర్ బ్రాండ్, రాములమ్మ విజయశాంతి ఓ రేంజ్‌లో విరుచుకుపడ్డారు.
#  Tokens: ['ఫైర్', 'బ్రాండ్', ',', 'రాములమ్మ', 'విజయశాంతి', 'ఓ', 'రేంజ్', 'లో', 'విరుచుకుపడ్డారు', '.']
#
#  Sentence 6: ఈ మేరకు ఫేస్‌బుక్‌లో పోస్ట్ పెట్టారు.
#  Tokens: ['ఈ', 'మేరకు', 'ఫేస్', 'బుక్', 'లో', 'పోస్ట్', 'పెట్టారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ‘‘తెలంగాణలో చాలా అభివృద్ధి చేసినమని చెబుతుండ్రు.
#  Tokens: ['‘', '‘', 'తెలంగాణలో', 'చాలా', 'అభివృద్ధి', 'చేసినమని', 'చెబుతుండ్రు', '.']
#
#  Sentence 2: బ్రిటిష్ వాళ్లు కూడా అభివృద్ధి చేసిండ్రు.
#  Tokens: ['బ్రిటిష్', 'వాళ్లు', 'కూడా', 'అభివృద్ధి', 'చేసిండ్రు', '.']
#
#  Sentence 3: దేశంలో రైల్వే లైన్లు వేసిండ్రు, రోడ్లేసిండ్రు.
#  Tokens: ['దేశంలో', 'రైల్వే', 'లైన్లు', 'వేసిండ్రు', ',', 'రోడ్లేసిండ్రు', '.']
#
#  Sentence 4: కానీ, భారత జాతి ఆత్మగౌరవం కోసం పోరాటం చేసింది.
#  Tokens: ['కానీ', ',', 'భారత', 'జాతి', 'ఆత్మగౌరవం', 'కోసం', 'పోరాటం', 'చేసింది', '.']
#
#  Sentence 5: అభివృద్ధి అన్నది ఆత్మగౌరవానికి ప్రత్యామ్నాయం కాదు.
#  Tokens: ['అభివృద్ధి', 'అన్నది', 'ఆత్మగౌరవానికి', 'ప్రత్యామ్నాయం', 'కాదు', '.']
#
#  Sentence 6: ప్రజలకు ప్రాతినిధ్యం లేదు.
#  Tokens: ['ప్రజలకు', 'ప్రాతినిధ్యం', 'లేదు', '.']
#
#  Sentence 7: ఏ అధికారులైనా తమ అభిప్రాయాలను ముఖ్యమంత్రితో చెప్పే పరిస్థితి ఉందా?’’ అని మంత్రి పదవికి రాజీనామా చేసిన సందర్భంలో ఈటెల అన్నారు.
#  Tokens: ['ఏ', 'అధికారులైనా', 'తమ', 'అభిప్రాయాలను', 'ముఖ్యమంత్రితో', 'చెప్పే', 'పరిస్థితి', 'ఉందా', '?', '’', '’', 'అని', 'మంత్రి', 'పదవికి', 'రాజీనామా', 'చేసిన', 'సందర్భంలో', 'ఈటెల', 'అన్నారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: వాతావరణ శాఖ తెలిపిన వివరాల ప్రకారం ఈ మాన్సూన్ సీజన్‌లో ఇంటీరియర్ ఒడిశా, కొంకణ్, గోవా తదితర ప్రాంతాలలో భారీ నుంచి అతి భారీ వర్షాలు, గుజరాత్‌లోని కొన్ని ప్రాంతాలలో భారీ నుంచి అతి భారీ వర్షాలు, తెలంగాణలోని పలు ప్రాంతాలలో భారీ వర్షాలు, కొన్ని ప్రాంతాలలో భారీ నుంచి అతి భారీ వర్షాలు, తూర్పు మధ్యప్రదేశ్, సౌరాష్ట్ర, విదర్భ, చత్తీస్ గఢ్, మధ్య మహారాష్ట్ర, సౌత్ ఇంటీరియర్ కర్ణాటకలలో భారీ నుంచి అతి భారీ వర్షాలు, కోస్టల్ కర్ణాటకలోని కొన్ని ప్రాంతాలలో, కేరళలో భారీ వర్షాలు, అసోం, మేఘాలయ, పశ్చిమ బెంగాల్, వెస్ట్ ఉత్తర ప్రదేశ్, నాగాలాండ్, మణిపూర్, మిజోరాం, త్రిపుర, ఉత్తరాఖండ్, ఈస్ట్ రాజస్థాన్, వెస్ట్ మధ్యప్రదేశ్, మరాట్వాడ, నార్త్ ఇంటీరియర్ కర్ణాటక, తమిళనాడులలోని కొన్ని ప్రాంతాల్లో భారీ వర్షాలు కురుస్తాయని తెలిపింది.
#  Tokens: ['వాతావరణ', 'శాఖ', 'తెలిపిన', 'వివరాల', 'ప్రకారం', 'ఈ', 'మాన్సూన్', 'సీజన్', 'లో', 'ఇంటీరియర్', 'ఒడిశా', ',', 'కొంకణ్', ',', 'గోవా', 'తదితర', 'ప్రాంతాలలో', 'భారీ', 'నుంచి', 'అతి', 'భారీ', 'వర్షాలు', ',', 'గుజరాత్', 'లోని', 'కొన్ని', 'ప్రాంతాలలో', 'భారీ', 'నుంచి', 'అతి', 'భారీ', 'వర్షాలు', ',', 'తెలంగాణలోని', 'పలు', 'ప్రాంతాలలో', 'భారీ', 'వర్షాలు', ',', 'కొన్ని', 'ప్రాంతాలలో', 'భారీ', 'నుంచి', 'అతి', 'భారీ', 'వర్షాలు', ',', 'తూర్పు', 'మధ్యప్రదేశ్', ',', 'సౌరాష్ట్ర', ',', 'విదర్భ', ',', 'చత్తీస్', 'గఢ్', ',', 'మధ్య', 'మహారాష్ట్ర', ',', 'సౌత్', 'ఇంటీరియర్', 'కర్ణాటకలలో', 'భారీ', 'నుంచి', 'అతి', 'భారీ', 'వర్షాలు', ',', 'కోస్టల్', 'కర్ణాటకలోని', 'కొన్ని', 'ప్రాంతాలలో', ',', 'కేరళలో', 'భారీ', 'వర్షాలు', ',', 'అసోం', ',', 'మేఘాలయ', ',', 'పశ్చిమ', 'బెంగాల్', ',', 'వెస్ట్', 'ఉత్తర', 'ప్రదేశ్', ',', 'నాగాలాండ్', ',', 'మణిపూర్', ',', 'మిజోరాం', ',', 'త్రిపుర', ',', 'ఉత్తరాఖండ్', ',', 'ఈస్ట్', 'రాజస్థాన్', ',', 'వెస్ట్', 'మధ్యప్రదేశ్', ',', 'మరాట్వాడ', ',', 'నార్త్', 'ఇంటీరియర్', 'కర్ణాటక', ',', 'తమిళనాడులలోని', 'కొన్ని', 'ప్రాంతాల్లో', 'భారీ', 'వర్షాలు', 'కురుస్తాయని', 'తెలిపింది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఈ నేపథ్యంలో భద్రతను కట్టుదిట్టం చేసినట్లు ఎయిర్ పోర్ట్ డైరెక్టర్ ఏకేసీ నాయర్ చెప్పారు.
#  Tokens: ['ఈ', 'నేపథ్యంలో', 'భద్రతను', 'కట్టుదిట్టం', 'చేసినట్లు', 'ఎయిర్', 'పోర్ట్', 'డైరెక్టర్', 'ఏకేసీ', 'నాయర్', 'చెప్పారు', '.']
#
#  Sentence 2: శనివారం ముంబై నుంచి వచ్చే విమానం లేదా శుక్రవారం రాత్రి అహ్మాదాబాద్ - ముంబై సెక్టార్ విమానంపై దాడి చేయనున్నట్లు వార్తలు వచ్చాయి.
#  Tokens: ['శనివారం', 'ముంబై', 'నుంచి', 'వచ్చే', 'విమానం', 'లేదా', 'శుక్రవారం', 'రాత్రి', 'అహ్మాదాబాద్', '-', 'ముంబై', 'సెక్టార్', 'విమానంపై', 'దాడి', 'చేయనున్నట్లు', 'వార్తలు', 'వచ్చాయి', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: బాలీవుడ్‌ స్టార్స్‌ లో 90 శాతం మంది డ్రగ్స్‌ తీసుకుంటారు అంటూ సంచలన వ్యాఖ్యలు చేసిన కంగనా రనౌత్‌ పూర్తి వివరాలు బయటకు లాగాలంటూ డిమాండ్‌ చేసిన విషయం తెల్సిందే.ఇదే సమయంలో టాలీవుడ్‌ నటి, బీజేపీ నాయకురాలు మాధవిలత కూడా డ్రగ్స్‌...
#  Tokens: ['బాలీవుడ్', 'స్టార్స్', 'లో', '90', 'శాతం', 'మంది', 'డ్రగ్స్', 'తీసుకుంటారు', 'అంటూ', 'సంచలన', 'వ్యాఖ్యలు', 'చేసిన', 'కంగనా', 'రనౌత్', 'పూర్తి', 'వివరాలు', 'బయటకు', 'లాగాలంటూ', 'డిమాండ్', 'చేసిన', 'విషయం', 'తెల్సిందే', '.', 'ఇదే', 'సమయంలో', 'టాలీవుడ్', 'నటి', ',', 'బీజేపీ', 'నాయకురాలు', 'మాధవిలత', 'కూడా', 'డ్రగ్స్', '.', '.', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కొయ్యూరు (జెడ్)లో వ్యవసాయానికి నీటి సరఫరా కింది వనరుల ద్వారా జరుగుతోంది.
#  Tokens: ['కొయ్యూరు', '(', 'జెడ్', ')', 'లో', 'వ్యవసాయానికి', 'నీటి', 'సరఫరా', 'కింది', 'వనరుల', 'ద్వారా', 'జరుగుతోంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ట్రెండ్ మార్చేసింది.
#  Tokens: ['ట్రెండ్', 'మార్చేసింది', '.']
#
#  Sentence 2: కేవలం అందాన్ని చూపించి ఆకట్టుకునే తంతుకు ఫుల్‌స్టాప్ పెట్టేసింది.
#  Tokens: ['కేవలం', 'అందాన్ని', 'చూపించి', 'ఆకట్టుకునే', 'తంతుకు', 'ఫుల్', 'స్టాప్', 'పెట్టేసింది', '.']
#
#  Sentence 3: గ్లామర్‌గా కనిపిస్తూనే..
#  Tokens: ['గ్లామర్', 'గా', 'కనిపిస్తూనే', '.', '.']
#
#  Sentence 4: పాత్రలో జీవించేందుకు ప్రయత్నిస్తోంది.
#  Tokens: ['పాత్రలో', 'జీవించేందుకు', 'ప్రయత్నిస్తోంది', '.']
#
#  Sentence 5: తను పోషించాల్సిన పాత్రకు ఒకింత ఔన్నత్యం ఉండేలా చూసుకుంటోంది.
#  Tokens: ['తను', 'పోషించాల్సిన', 'పాత్రకు', 'ఒకింత', 'ఔన్నత్యం', 'ఉండేలా', 'చూసుకుంటోంది', '.']
#
#  Sentence 6: హీరో సరసన అందాలూరించే అపరంజిలా గంతులేయడానికో..
#  Tokens: ['హీరో', 'సరసన', 'అందాలూరించే', 'అపరంజిలా', 'గంతులేయడానికో', '.', '.']
#
#  Sentence 7: హద్దుదాటే రొమాంటిక్ సన్నివేశాలతో ఆడియన్స్‌ని మురిపించడానికో పరిమితమయ్యే పాత్రలు వస్తుంటే -వద్దని నిర్మొహమాటంగా తిప్పికొడుతున్న కథానాయికల సంఖ్య పెరుగుతోంది.
#  Tokens: ['హద్దుదాటే', 'రొమాంటిక్', 'సన్నివేశాలతో', 'ఆడియన్స్', 'ని', 'మురిపించడానికో', 'పరిమితమయ్యే', 'పాత్రలు', 'వస్తుంటే', '-', 'వద్దని', 'నిర్మొహమాటంగా', 'తిప్పికొడుతున్న', 'కథానాయికల', 'సంఖ్య', 'పెరుగుతోంది', '.']
#
#  Sentence 8: గ్లామర్ పాత్రలకు నిత్యమీనన్ నో చెప్పిందనో..
#  Tokens: ['గ్లామర్', 'పాత్రలకు', 'నిత్యమీనన్', 'నో', 'చెప్పిందనో', '.', '.']
#
#  Sentence 9: ఫలానా సినిమాలో ప్రాధాన్యత లేని పాత్రను సమంత కాదనుకుందనో
#  Tokens: ['ఫలానా', 'సినిమాలో', 'ప్రాధాన్యత', 'లేని', 'పాత్రను', 'సమంత', 'కాదనుకుందనో']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: చేతిలో శిక్షణ కార్యక్రమం ఒక స్వతంత్ర ఎక్సర్సైజేస్, కానీ అథ్లెట్ యొక్క మొత్తం శిక్షణ కార్యక్రమంలో భాగంగా మాత్రమే కాదు గుర్తుచేసుకున్నారు.
#  Tokens: ['చేతిలో', 'శిక్షణ', 'కార్యక్రమం', 'ఒక', 'స్వతంత్ర', 'ఎక్సర్సైజేస్', ',', 'కానీ', 'అథ్లెట్', 'యొక్క', 'మొత్తం', 'శిక్షణ', 'కార్యక్రమంలో', 'భాగంగా', 'మాత్రమే', 'కాదు', 'గుర్తుచేసుకున్నారు', '.']
#
#  Sentence 2: అయితే, తీవ్ర బిల్డ్ చేయి కండరాలు కోసం రెండుసార్లు మద్దతిస్తుంది ఒక పెద్ద బరువు శిక్షణ ఒకసారి ఒక వారం యొక్క చక్రం శిక్షణలో వాటిని వ్యాయామం ఉన్నాయి, మరియు రెండవ - ఉపశమనాన్ని.
#  Tokens: ['అయితే', ',', 'తీవ్ర', 'బిల్డ్', 'చేయి', 'కండరాలు', 'కోసం', 'రెండుసార్లు', 'మద్దతిస్తుంది', 'ఒక', 'పెద్ద', 'బరువు', 'శిక్షణ', 'ఒకసారి', 'ఒక', 'వారం', 'యొక్క', 'చక్రం', 'శిక్షణలో', 'వాటిని', 'వ్యాయామం', 'ఉన్నాయి', ',', 'మరియు', 'రెండవ', '-', 'ఉపశమనాన్ని', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తాగు నీరు.
#  Tokens: ['తాగు', 'నీరు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: అనూహ్యమైన రీతిలో నిరసన వ్యక్తం కావడంతో పత్రిక ఎడిటర్ దిగొచ్చి వెంటనే క్షమాపణ చెప్పారు.
#  Tokens: ['అనూహ్యమైన', 'రీతిలో', 'నిరసన', 'వ్యక్తం', 'కావడంతో', 'పత్రిక', 'ఎడిటర్', 'దిగొచ్చి', 'వెంటనే', 'క్షమాపణ', 'చెప్పారు', '.']
#
#  Sentence 2: ఇందుకు బాధ్యులైన వారిపై చర్యలు తీసుకుంటామని కూడా హామీ ఇచ్చారు.
#  Tokens: ['ఇందుకు', 'బాధ్యులైన', 'వారిపై', 'చర్యలు', 'తీసుకుంటామని', 'కూడా', 'హామీ', 'ఇచ్చారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తాము తలచుకుంటే టీఆర్ఎస్ పార్టీ ఉనికి కోల్పోతుందని హెచ్చరించారు.
#  Tokens: ['తాము', 'తలచుకుంటే', 'టీఆర్ఎస్', 'పార్టీ', 'ఉనికి', 'కోల్పోతుందని', 'హెచ్చరించారు', '.']
#
#  Sentence 2: గత ఎన్నికల్లో తమ పార్టీలోని నేతల మధ్య సమన్వయం లేకనే ఓడిపోయాం తప్ప సత్తా లేక కాదన్నారు.
#  Tokens: ['గత', 'ఎన్నికల్లో', 'తమ', 'పార్టీలోని', 'నేతల', 'మధ్య', 'సమన్వయం', 'లేకనే', 'ఓడిపోయాం', 'తప్ప', 'సత్తా', 'లేక', 'కాదన్నారు', '.']
#
#  Sentence 3: క్యాంపు రాజకీయాలకు, అధికార దుర్వినియోగానికి టీఆర్ఎస్ కేరాఫ్ అడ్రస్‌గా మారిందన్నారు.
#  Tokens: ['క్యాంపు', 'రాజకీయాలకు', ',', 'అధికార', 'దుర్వినియోగానికి', 'టీఆర్ఎస్', 'కేరాఫ్', 'అడ్రస్', 'గా', 'మారిందన్నారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: సంస్థ ఉద్యోగులకు బెదిరింపులు కూడా ఎదురయ్యాయి.
#  Tokens: ['సంస్థ', 'ఉద్యోగులకు', 'బెదిరింపులు', 'కూడా', 'ఎదురయ్యాయి', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: రెంజల్‌, మే 1: ఎమ్మెల్సీ కల్వకుంట్ల కవిత ఇద్దరు కొవిడ్‌ పేషెంట్లకు సకాలంలో రెమ్‌డెసివిర్‌ ఇంజక్షన్లు ఇప్పించి వారి కుటుంబాల్లో భరోసా నింపారు.
#  Tokens: ['రెంజల్', ',', 'మే', '1', ':', 'ఎమ్మెల్సీ', 'కల్వకుంట్ల', 'కవిత', 'ఇద్దరు', 'కొవిడ్', 'పేషెంట్లకు', 'సకాలంలో', 'రెమ్', 'డెసివిర్', 'ఇంజక్షన్లు', 'ఇప్పించి', 'వారి', 'కుటుంబాల్లో', 'భరోసా', 'నింపారు', '.']
#
#  Sentence 2: నిజామాబాద్‌ జిల్లా రెంజల్‌ మండలం సాటాపూర్‌ గ్రామానికి చెందిన ఖాజాఖాన్‌ భార్య హతియాబేగం, కూతురు మునీరా కౌసర్‌ కొవిడ్‌ బారినపడి జిల్లా కేంద్రంలోని ఓ ప్రైవేట్‌ దవాఖాన లో చేరారు.
#  Tokens: ['నిజామాబాద్', 'జిల్లా', 'రెంజల్', 'మండలం', 'సాటాపూర్', 'గ్రామానికి', 'చెందిన', 'ఖాజాఖాన్', 'భార్య', 'హతియాబేగం', ',', 'కూతురు', 'మునీరా', 'కౌసర్', 'కొవిడ్', 'బారినపడి', 'జిల్లా', 'కేంద్రంలోని', 'ఓ', 'ప్రైవేట్', 'దవాఖాన', 'లో', 'చేరారు', '.']
#
#  Sentence 3: ఇద్దరికీ పల్స్‌రేట్‌ పడిపోవడంతో రెమ్‌డెసివిర్‌ ఇంజక్షన్‌ ఇవ్వాలని కుటుంబీకులకు వైద్యులు సూచించారు.
#  Tokens: ['ఇద్దరికీ', 'పల్స్', 'రేట్', 'పడిపోవడంతో', 'రెమ్', 'డెసివిర్', 'ఇంజక్షన్', 'ఇవ్వాలని', 'కుటుంబీకులకు', 'వైద్యులు', 'సూచించారు', '.']
#
#  Sentence 4: మార్కెట్‌లో కొరత, ప్రైవేట్‌లో అధిక రేటు కారణంగా ఇంజక్షన్లు కొనలేని దీనస్థితి తెలుసుకున్న గ్రామ సర్పంచ్‌ వికార్‌పాషా..
#  Tokens: ['మార్కెట్', 'లో', 'కొరత', ',', 'ప్రైవేట్', 'లో', 'అధిక', 'రేటు', 'కారణంగా', 'ఇంజక్షన్లు', 'కొనలేని', 'దీనస్థితి', 'తెలుసుకున్న', 'గ్రామ', 'సర్పంచ్', 'వికార్', 'పాషా', '.', '.']
#
#  Sentence 5: శనివారం ఎమ్మెల్సీ కవితకు ఫోన్‌ ద్వారా సమస్యను వివరించారు.
#  Tokens: ['శనివారం', 'ఎమ్మెల్సీ', 'కవితకు', 'ఫోన్', 'ద్వారా', 'సమస్యను', 'వివరించారు', '.']
#
#  Sentence 6: తక్షణమే స్పందించిన ఆమె..
#  Tokens: ['తక్షణమే', 'స్పందించిన', 'ఆమె', '.', '.']
#
#  Sentence 7: జిల్లా ఉన్నతాధికారులతో మాట్లాడి గంటలోపే ఇంజక్షన్లను ఉచితంగా ఇప్పించారు.
#  Tokens: ['జిల్లా', 'ఉన్నతాధికారులతో', 'మాట్లాడి', 'గంటలోపే', 'ఇంజక్షన్లను', 'ఉచితంగా', 'ఇప్పించారు', '.']
#
#  Sentence 8: ఆపత్కాలంలో అండగా నిలిచిన ఎమ్మెల్సీ కవితకు సర్పంచ్‌ కృతజ్ఞతలు తెలిపారు.
#  Tokens: ['ఆపత్కాలంలో', 'అండగా', 'నిలిచిన', 'ఎమ్మెల్సీ', 'కవితకు', 'సర్పంచ్', 'కృతజ్ఞతలు', 'తెలిపారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఈ మేరకు ఆగ్నేయ తీరంలో సైనిక మోహరింపులను నానాటికీ పెంచుతోంది.
#  Tokens: ['ఈ', 'మేరకు', 'ఆగ్నేయ', 'తీరంలో', 'సైనిక', 'మోహరింపులను', 'నానాటికీ', 'పెంచుతోంది', '.']
#
#  Sentence 2: ఇదంతా తైవాన్‌ దురాక్రమణ కోసమేనని రక్షణ విశ్లేషకులు అనుమానిస్తున్నారని పత్రిక చెప్పింది.
#  Tokens: ['ఇదంతా', 'తైవాన్', 'దురాక్రమణ', 'కోసమేనని', 'రక్షణ', 'విశ్లేషకులు', 'అనుమానిస్తున్నారని', 'పత్రిక', 'చెప్పింది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కేంద్ర ప్రభుత్వం జమ్మూకశ్మీర్‌కు ప్రత్యేక ప్రతిపత్తిని తొలగిస్తూ, ఆర్టికల్ 370ని రద్దు చేస్తూ తీసుకున్న నిర్ణయం చట్టబద్ధమైనదేనా అని ప్రశ్నిస్తూ దాఖలైన అనేక పిటిషన్లు ప్రస్తుతం సుప్రీం కోర్టు ముందున్నాయి.
#  Tokens: ['కేంద్ర', 'ప్రభుత్వం', 'జమ్మూకశ్మీర్', 'కు', 'ప్రత్యేక', 'ప్రతిపత్తిని', 'తొలగిస్తూ', ',', 'ఆర్టికల్', 'ని', 'రద్దు', 'చేస్తూ', 'తీసుకున్న', 'నిర్ణయం', 'చట్టబద్ధమైనదేనా', 'అని', 'ప్రశ్నిస్తూ', 'దాఖలైన', 'అనేక', 'పిటిషన్లు', 'ప్రస్తుతం', 'సుప్రీం', 'కోర్టు', 'ముందున్నాయి', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తాను వ్యక్తిగతంగా ఎవర్నీ ఉద్దేశించి వ్యాఖ్యలు చేయలేదని మల్లాది వాసు చెప్పారు.
#  Tokens: ['తాను', 'వ్యక్తిగతంగా', 'ఎవర్నీ', 'ఉద్దేశించి', 'వ్యాఖ్యలు', 'చేయలేదని', 'మల్లాది', 'వాసు', 'చెప్పారు', '.']
#
#  Sentence 2: ఎన్టీ రామారావు కుటుంబం మీద ఉన్న అభిమానం, కమ్మ కులానికి జరుగుతోన్న అన్యాయం చూసి బాధపడి వ్యాఖ్యలు చేశానని తెలిపారు.
#  Tokens: ['ఎన్టీ', 'రామారావు', 'కుటుంబం', 'మీద', 'ఉన్న', 'అభిమానం', ',', 'కమ్మ', 'కులానికి', 'జరుగుతోన్న', 'అన్యాయం', 'చూసి', 'బాధపడి', 'వ్యాఖ్యలు', 'చేశానని', 'తెలిపారు', '.']
#
#  Sentence 3: తనకు ఏ రకమైన నేర సంస్కృతి లేదని..
#  Tokens: ['తనకు', 'ఏ', 'రకమైన', 'నేర', 'సంస్కృతి', 'లేదని', '.', '.']
#
#  Sentence 4: హత్యలు చేయించే సంస్కృతి తనది కాదని వ్యాఖ్యానించారు.
#  Tokens: ['హత్యలు', 'చేయించే', 'సంస్కృతి', 'తనది', 'కాదని', 'వ్యాఖ్యానించారు', '.']
#
#  Sentence 5: గత కొంతకాలంగా ఆంధ్రప్రదేశ్ అసెంబ్లీలో జరిగిన పరిణామాలు చూసి బాధతో మాట్లాడినట్లు పేర్కొన్నారు.
#  Tokens: ['గత', 'కొంతకాలంగా', 'ఆంధ్రప్రదేశ్', 'అసెంబ్లీలో', 'జరిగిన', 'పరిణామాలు', 'చూసి', 'బాధతో', 'మాట్లాడినట్లు', 'పేర్కొన్నారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కరీంనగర్: హుజురాబాద్‌లో ఉపఎన్నిక వేడి రాజుకుంది.
#  Tokens: ['కరీంనగర్', ':', 'హుజురాబాద్', 'లో', 'ఉపఎన్నిక', 'వేడి', 'రాజుకుంది', '.']
#
#  Sentence 2: ఈటల రాజేందర్ రాజీనామాతో మరోసారి ఉప ఎన్నిక అనివార్యం కాబోతోంది.
#  Tokens: ['ఈటల', 'రాజేందర్', 'రాజీనామాతో', 'మరోసారి', 'ఉప', 'ఎన్నిక', 'అనివార్యం', 'కాబోతోంది', '.']
#
#  Sentence 3: దీంతో అన్ని పార్టీలు హుజూరాబాద్ నియోజకవర్గంపై దృష్టి సారించాయి.
#  Tokens: ['దీంతో', 'అన్ని', 'పార్టీలు', 'హుజూరాబాద్', 'నియోజకవర్గంపై', 'దృష్టి', 'సారించాయి', '.']
#
#  Sentence 4: ఇక్కడ గెలిచి నియోజకవర్గంలో టీఆర్ఎస్‌కు ఎదురు లేదని ఆ పార్టీ అధిష్టానం, నేతలు భావిస్తున్నారు.
#  Tokens: ['ఇక్కడ', 'గెలిచి', 'నియోజకవర్గంలో', 'టీఆర్ఎస్', 'కు', 'ఎదురు', 'లేదని', 'ఆ', 'పార్టీ', 'అధిష్టానం', ',', 'నేతలు', 'భావిస్తున్నారు', '.']
#
#  Sentence 5: ఇటు బీజేపీలో చేరిన ఈటల రాజేందర్ మరోసారి ఇక్కడ నుంచి ఎమ్మెల్యేగా గెలిచి టీఆర్ఎస్‌కు తన సత్తా చూపాలని యోచిస్తున్నారు.
#  Tokens: ['ఇటు', 'బీజేపీలో', 'చేరిన', 'ఈటల', 'రాజేందర్', 'మరోసారి', 'ఇక్కడ', 'నుంచి', 'ఎమ్మెల్యేగా', 'గెలిచి', 'టీఆర్ఎస్', 'కు', 'తన', 'సత్తా', 'చూపాలని', 'యోచిస్తున్నారు', '.']
#
#  Sentence 6: మరోవైపు కాంగ్రెస్ కూడా పట్టు నిలుపుకునేందుకు ప్రయత్నిస్తోంది.
#  Tokens: ['మరోవైపు', 'కాంగ్రెస్', 'కూడా', 'పట్టు', 'నిలుపుకునేందుకు', 'ప్రయత్నిస్తోంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తెలంగాణలో కొద్దిరోజుల నుంచి భారీ వర్షాలు కురుస్తున్న నేపథ్యంలో ప్రభుత్వం ఈ అంశంపై దృష్టి పెట్టింది.
#  Tokens: ['తెలంగాణలో', 'కొద్దిరోజుల', 'నుంచి', 'భారీ', 'వర్షాలు', 'కురుస్తున్న', 'నేపథ్యంలో', 'ప్రభుత్వం', 'ఈ', 'అంశంపై', 'దృష్టి', 'పెట్టింది', '.']
#
#  Sentence 2: మరికొన్ని రోజుల పాటు రాష్ట్రంలో వర్షాలు కురిసే అవకాశం ఉండటంతో..
#  Tokens: ['మరికొన్ని', 'రోజుల', 'పాటు', 'రాష్ట్రంలో', 'వర్షాలు', 'కురిసే', 'అవకాశం', 'ఉండటంతో', '.', '.']
#
#  Sentence 3: పరిస్థితులపై మున్సిపల్ శాఖ మంత్రి కేటీఆర్ సమీక్ష నిర్వహించారు.
#  Tokens: ['పరిస్థితులపై', 'మున్సిపల్', 'శాఖ', 'మంత్రి', 'కేటీఆర్', 'సమీక్ష', 'నిర్వహించారు', '.']
#
#  Sentence 4: హైదరాబాద్ నగరంతో పాటు రాష్ట్రంలోని పరిస్థితులపై ఆయన ఆరా తీశారు.
#  Tokens: ['హైదరాబాద్', 'నగరంతో', 'పాటు', 'రాష్ట్రంలోని', 'పరిస్థితులపై', 'ఆయన', 'ఆరా', 'తీశారు', '.']
#
#  Sentence 5: మరికొన్ని రోజుల పాటు రాష్ట్రంలో వర్షాలు పడే అవకాశం ఉండటంతో..
#  Tokens: ['మరికొన్ని', 'రోజుల', 'పాటు', 'రాష్ట్రంలో', 'వర్షాలు', 'పడే', 'అవకాశం', 'ఉండటంతో', '.', '.']
#
#  Sentence 6: రానున్న రెండు వారాల పాటు అధికారులకు సెలవులు రద్దు చేస్తున్నట్లు కేటీఆర్ ప్రకటించారు.
#  Tokens: ['రానున్న', 'రెండు', 'వారాల', 'పాటు', 'అధికారులకు', 'సెలవులు', 'రద్దు', 'చేస్తున్నట్లు', 'కేటీఆర్', 'ప్రకటించారు', '.']
#
#  Sentence 7: నిరంతరం క్షేత్రంలో ఉంటూ ఆకస్మిక తనిఖీలు చేస్తూ పర్యవేక్షణ చేయాలని ఆదేశించారు.
#  Tokens: ['నిరంతరం', 'క్షేత్రంలో', 'ఉంటూ', 'ఆకస్మిక', 'తనిఖీలు', 'చేస్తూ', 'పర్యవేక్షణ', 'చేయాలని', 'ఆదేశించారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: బెంగళూరు: కేఫ్ కాఫీ డే ఫౌండర్ వీజీ సిద్ధార్థ ఆత్మహత్య చేసుకున్న దాదాపు 15రోజుల తర్వాత కంపెనీకి చెందిన ఆస్తులను విక్రయించాలని కాఫీ డే ఎంటర్‌ప్రైజెస్ లిమిటెడ్ (CDEL) నిర్ణయించింది.
#  Tokens: ['బెంగళూరు', ':', 'కేఫ్', 'కాఫీ', 'డే', 'ఫౌండర్', 'వీజీ', 'సిద్ధార్థ', 'ఆత్మహత్య', 'చేసుకున్న', 'దాదాపు', 'రోజుల', 'తర్వాత', 'కంపెనీకి', 'చెందిన', 'ఆస్తులను', 'విక్రయించాలని', 'కాఫీ', 'డే', 'ఎంటర్', 'ప్రైజెస్', 'లిమిటెడ్', '(', 'CDEL', ')', 'నిర్ణయించింది', '.']
#
#  Sentence 2: కాఫీ డే అనుబంధ సంస్థ టాంగ్‌లింగ్ డెవలప్‌మెంట్స్ లిమిటెడ్‌కు చెందిన గ్లోబల్ విలేజ్ టెక్ పార్క్‌ను అమెరికా బైఔట్ దిగ్గజం బ్లాక్‌స్టోన్‌కు రూ.2,600 కోట్ల నుంచి రూ.3,000 కోట్ల మధ్య విక్రయించాలని నిర్ణయించారని తెలుస్తోంది.
#  Tokens: ['కాఫీ', 'డే', 'అనుబంధ', 'సంస్థ', 'టాంగ్', 'లింగ్', 'డెవలప్', 'మెంట్స్', 'లిమిటెడ్', 'కు', 'చెందిన', 'గ్లోబల్', 'విలేజ్', 'టెక్', 'పార్క్', 'ను', 'అమెరికా', 'బైఔట్', 'దిగ్గజం', 'బ్లాక్', 'స్టోన్', 'కు', 'రూ', '.', '2', ',', '600', 'కోట్ల', 'నుంచి', 'రూ', '.', '3', ',', '000', 'కోట్ల', 'మధ్య', 'విక్రయించాలని', 'నిర్ణయించారని', 'తెలుస్తోంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తాళ్ళరేవు హైస్కూలు, బాపట్ల వ్యవసాయ కళాశాల, బాలికల హైస్కూలుకు విరివిగా దానం ఇచ్చారు.
#  Tokens: ['తాళ్ళరేవు', 'హైస్కూలు', ',', 'బాపట్ల', 'వ్యవసాయ', 'కళాశాల', ',', 'బాలికల', 'హైస్కూలుకు', 'విరివిగా', 'దానం', 'ఇచ్చారు', '.']
#
#  Sentence 2: తిరుపతి, శ్రీశైలం, ఋషికేశ్ లలో సత్రాలకు విరాళాలు ఇచ్చారు.
#  Tokens: ['తిరుపతి', ',', 'శ్రీశైలం', ',', 'ఋషికేశ్', 'లలో', 'సత్రాలకు', 'విరాళాలు', 'ఇచ్చారు', '.']
#
#  Sentence 3: భద్రాచల రామాలయ నిర్మాణం కొరకు కల్లూరి చంద్రమౌళి గారికి 50 వేలు విరాళం ఇచ్చారు.
#  Tokens: ['భద్రాచల', 'రామాలయ', 'నిర్మాణం', 'కొరకు', 'కల్లూరి', 'చంద్రమౌళి', 'గారికి', '50', 'వేలు', 'విరాళం', 'ఇచ్చారు', '.']
#
#  Sentence 4: విజయవాడ లయోలా కళాశాలకు , తెనాలి వి.యస్.ఆర్ కాలేజీ, నిడిబ్రోలు కాలేజీ లకు కూడా విరాళాలు ఇచ్చారు.
#  Tokens: ['విజయవాడ', 'లయోలా', 'కళాశాలకు', ',', 'తెనాలి', 'వి', '.', 'యస్', '.', 'ఆర్', 'కాలేజీ', ',', 'నిడిబ్రోలు', 'కాలేజీ', 'లకు', 'కూడా', 'విరాళాలు', 'ఇచ్చారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: వ్యక్తిగత జీవితం.
#  Tokens: ['వ్యక్తిగత', 'జీవితం', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: అటువంటి అల్లు అర్జున్ కి హాట్సాఫ్ , హాట్సాఫ్.
#  Tokens: ['అటువంటి', 'అల్లు', 'అర్జున్', 'కి', 'హాట్సాఫ్', ',', 'హాట్సాఫ్', '.']
#
#  Sentence 2: అతను ఎంత స్టార్ హీరో.
#  Tokens: ['అతను', 'ఎంత', 'స్టార్', 'హీరో', '.']
#
#  Sentence 3: ఈ సినిమాలో గోనగన్నారెడ్డి పాత్రా నేను చేస్తానని అయన ముందుకొచ్చారు.
#  Tokens: ['ఈ', 'సినిమాలో', 'గోనగన్నారెడ్డి', 'పాత్రా', 'నేను', 'చేస్తానని', 'అయన', 'ముందుకొచ్చారు', '.']
#
#  Sentence 4: అందుకే మనం అనుష్క నుంచి అంతా అందరు రుణపడి ఉండాలి.
#  Tokens: ['అందుకే', 'మనం', 'అనుష్క', 'నుంచి', 'అంతా', 'అందరు', 'రుణపడి', 'ఉండాలి', '.']
#
#  Sentence 5: ఈ సినిమా కథ విన్న అనుష్క వెంటనే చేస్తానని ఒప్పుకుంది.
#  Tokens: ['ఈ', 'సినిమా', 'కథ', 'విన్న', 'అనుష్క', 'వెంటనే', 'చేస్తానని', 'ఒప్పుకుంది', '.']
#
#  Sentence 6: చరిత్ర తెరపైకి చూపిస్తానని అంటే నేను మున్డుంటాను సర్ అని అన్నారు.
#  Tokens: ['చరిత్ర', 'తెరపైకి', 'చూపిస్తానని', 'అంటే', 'నేను', 'మున్డుంటాను', 'సర్', 'అని', 'అన్నారు', '.']
#
#  Sentence 7: అనుష్క శ్రమ ఇక్కడ మీ ధ్వనిలో వినిపించాలి.
#  Tokens: ['అనుష్క', 'శ్రమ', 'ఇక్కడ', 'మీ', 'ధ్వనిలో', 'వినిపించాలి', '.']
#
#  Sentence 8: పరిశ్రమలోని స్టార్ హీరోలు తమ సినిమాలకి ఎంత కష్టపడుటారో....అనుష్క అలాగే కష్టపడింది.
#  Tokens: ['పరిశ్రమలోని', 'స్టార్', 'హీరోలు', 'తమ', 'సినిమాలకి', 'ఎంత', 'కష్టపడుటారో', '.', '.', '.', '.', 'అనుష్క', 'అలాగే', 'కష్టపడింది', '.']
#
#  Sentence 9: రుద్రమదేవి ఎలా ఉంటుందో తెలియదు....ఈమెన్ చూస్తె తెలిసిపోతుంది.
#  Tokens: ['రుద్రమదేవి', 'ఎలా', 'ఉంటుందో', 'తెలియదు', '.', '.', '.', '.', 'ఈమెన్', 'చూస్తె', 'తెలిసిపోతుంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఉన్నది ఎంత?
#  Tokens: ['ఉన్నది', 'ఎంత', '?']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: పత్రికా విలేకరులు ఇలాటి ప్రశ్నలకు సమాధానం పొందడం ద్వారా విషయ సేకరణ చేస్తుంటారు.
#  Tokens: ['పత్రికా', 'విలేకరులు', 'ఇలాటి', 'ప్రశ్నలకు', 'సమాధానం', 'పొందడం', 'ద్వారా', 'విషయ', 'సేకరణ', 'చేస్తుంటారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఆసుపత్రిలో సాయి ధరమ్‌ తేజ్‌కు చికిత్స చేస్తున్న వీడియోలు బయటకు రావడం చూశాం.
#  Tokens: ['ఆసుపత్రిలో', 'సాయి', 'ధరమ్', 'తేజ్', 'కు', 'చికిత్స', 'చేస్తున్న', 'వీడియోలు', 'బయటకు', 'రావడం', 'చూశాం', '.']
#
#  Sentence 2: అయితే ఈ వీడియోలపై ఆగ్రహం వ్యక్తం చేసిన నిఖిల్..
#  Tokens: ['అయితే', 'ఈ', 'వీడియోలపై', 'ఆగ్రహం', 'వ్యక్తం', 'చేసిన', 'నిఖిల్', '.', '.']
#
#  Sentence 3: ఇది చాలా బాధాకరం అని పేర్కొంటూ ట్వీట్ చేశారు.
#  Tokens: ['ఇది', 'చాలా', 'బాధాకరం', 'అని', 'పేర్కొంటూ', 'ట్వీట్', 'చేశారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: 3.
#  Tokens: ['3', '.']
#
#  Sentence 2: మూడో వన్డే డిసెంబరు 1న- మనూక ఓవెల్ (8:30 AM)
#  Tokens: ['మూడో', 'వన్డే', 'డిసెంబరు', 'న', '-', 'మనూక', 'ఓవెల్', '(', '8', ':', '30', 'AM', ')']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కాపులను ఇంతగా సతాయించిన చంద్రబాబుకు పవన్ మద్దతు పలకటాన్ని కాపు నేతలు తట్టుకోలేకపోతున్నారు.
#  Tokens: ['కాపులను', 'ఇంతగా', 'సతాయించిన', 'చంద్రబాబుకు', 'పవన్', 'మద్దతు', 'పలకటాన్ని', 'కాపు', 'నేతలు', 'తట్టుకోలేకపోతున్నారు', '.']
#
#  Sentence 2: అందుకనే జనసేనకు మద్దతుగా నిలవకూడదని కాపుల్లో చర్చలు జరుగుతున్నాయట.
#  Tokens: ['అందుకనే', 'జనసేనకు', 'మద్దతుగా', 'నిలవకూడదని', 'కాపుల్లో', 'చర్చలు', 'జరుగుతున్నాయట', '.']
#
#  Sentence 3: మరి ఎన్నికల తేదీ దగ్గర పడేకొద్దీ చర్చల జోరు పెరిగితే పాపం పవన్ పరిస్ధితి రాబోయే ఎన్నికల్లో ఘోరంగా తయారవటం ఖాయం.
#  Tokens: ['మరి', 'ఎన్నికల', 'తేదీ', 'దగ్గర', 'పడేకొద్దీ', 'చర్చల', 'జోరు', 'పెరిగితే', 'పాపం', 'పవన్', 'పరిస్ధితి', 'రాబోయే', 'ఎన్నికల్లో', 'ఘోరంగా', 'తయారవటం', 'ఖాయం', '.']
#
#  Sentence 4: అందుకనే పవన్ కన్నా సోదరుడు చిరంజీవే నయమనే వాదన కూడా కాపుల్లో బయలుదేరింది.
#  Tokens: ['అందుకనే', 'పవన్', 'కన్నా', 'సోదరుడు', 'చిరంజీవే', 'నయమనే', 'వాదన', 'కూడా', 'కాపుల్లో', 'బయలుదేరింది', '.']
#
#  Sentence 5: పాపం చంద్రబాబును నమ్ముకున్నందుకు పవన్ కు చివరకు మట్టే మిగిలేట్లుంది.
#  Tokens: ['పాపం', 'చంద్రబాబును', 'నమ్ముకున్నందుకు', 'పవన్', 'కు', 'చివరకు', 'మట్టే', 'మిగిలేట్లుంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: మనతెలంగాణ/కామారెడ్డి: తెలంగాణ రాష్ట్రంలో ప్రభుత్వ నిర్లక్ష్యం వల్లే మొన్నటివరకు రైతులు ఇప్పుడు నిరుద్యోగులు ఆత్మహత్యలు చేసుకు ంటున్నారని శాసన మండలి ప్రతిపక్షనేత షబ్బీర్ అలీ అన్నారు.
#  Tokens: ['మనతెలంగాణ', '/', 'కామారెడ్డి', ':', 'తెలంగాణ', 'రాష్ట్రంలో', 'ప్రభుత్వ', 'నిర్లక్ష్యం', 'వల్లే', 'మొన్నటివరకు', 'రైతులు', 'ఇప్పుడు', 'నిరుద్యోగులు', 'ఆత్మహత్యలు', 'చేసుకు', 'ంటున్నారని', 'శాసన', 'మండలి', 'ప్రతిపక్షనేత', 'షబ్బీర్', 'అలీ', 'అన్నారు', '.']
#
#  Sentence 2: గురు వారం ఆయన కామారెడ్డి జిల్లా కేంద్రంలోని ఏరియా ఆసుపత్రిలో బుధ వారం ఉద్యోగం రాదని తన తల్లిదండ్రుల శ్రమ వృధా అయిపోయిం దని రామారెడ్డి మండలం అన్నారం గ్రామానికి చెందిన విద్యా వలంటీర్ సుప్రజ ఆత్మహత్య చేసుకుంది.
#  Tokens: ['గురు', 'వారం', 'ఆయన', 'కామారెడ్డి', 'జిల్లా', 'కేంద్రంలోని', 'ఏరియా', 'ఆసుపత్రిలో', 'బుధ', 'వారం', 'ఉద్యోగం', 'రాదని', 'తన', 'తల్లిదండ్రుల', 'శ్రమ', 'వృధా', 'అయిపోయిం', 'దని', 'రామారెడ్డి', 'మండలం', 'అన్నారం', 'గ్రామానికి', 'చెందిన', 'విద్యా', 'వలంటీర్', 'సుప్రజ', 'ఆత్మహత్య', 'చేసుకుంది', '.']
#
#  Sentence 3: ఆమె మృతదేహాన్ని చూసి అక్కడే ఉన్న వారి కుటుంబ సభ్యులను పరామర్శించిన అనంతరం ఆయన మాట్లా డుతూ తెలంగాణ రాష్ట్రం ఏర్పడితే మన సమస్యలన్ని తీరి మన ఉద్యో గాలన్నీ మనకే వస్తాయని నమ్మిన యువత నేడు నాలుగు సంవత్సరాలు గడిచిపోయిన ఉద్యోగాలు రాకపోవడంతో ఉద్యోగాలు రావని మనస్థా పానికి గురై ఆత్మహత్యలు చేసుకుంటున్నారన్నారు.
#  Tokens: ['ఆమె', 'మృతదేహాన్ని', 'చూసి', 'అక్కడే', 'ఉన్న', 'వారి', 'కుటుంబ', 'సభ్యులను', 'పరామర్శించిన', 'అనంతరం', 'ఆయన', 'మాట్లా', 'డుతూ', 'తెలంగాణ', 'రాష్ట్రం', 'ఏర్పడితే', 'మన', 'సమస్యలన్ని', 'తీరి', 'మన', 'ఉద్యో', 'గాలన్నీ', 'మనకే', 'వస్తాయని', 'నమ్మిన', 'యువత', 'నేడు', 'నాలుగు', 'సంవత్సరాలు', 'గడిచిపోయిన', 'ఉద్యోగాలు', 'రాకపోవడంతో', 'ఉద్యోగాలు', 'రావని', 'మనస్థా', 'పానికి', 'గురై', 'ఆత్మహత్యలు', 'చేసుకుంటున్నారన్నారు', '.']
#
#  Sentence 4: మొన్న యూనివర్సి టిలు మురళీ ముదిరాజ్ కాగా నేడు సుప్రజ ఆత్మహత్య చేసుకుందని ఇలాంటి సంఘటనలు జరగడం బాధాకరమన్నారు.
#  Tokens: ['మొన్న', 'యూనివర్సి', 'టిలు', 'మురళీ', 'ముదిరాజ్', 'కాగా', 'నేడు', 'సుప్రజ', 'ఆత్మహత్య', 'చేసుకుందని', 'ఇలాంటి', 'సంఘటనలు', 'జరగడం', 'బాధాకరమన్నారు', '.']
#
#  Sentence 5: దీనిని రాజకీయం చేయకుండా కెసిఆర్ వెంటనే డియస్సీ ప్రకటించి ఉద్యోగాలను భర్తీ చేయాలన్నారు.
#  Tokens: ['దీనిని', 'రాజకీయం', 'చేయకుండా', 'కెసిఆర్', 'వెంటనే', 'డియస్సీ', 'ప్రకటించి', 'ఉద్యోగాలను', 'భర్తీ', 'చేయాలన్నారు', '.']
#
#  Sentence 6: ప్రగతి భవన నిర్మాణం కోసం రూ.
#  Tokens: ['ప్రగతి', 'భవన', 'నిర్మాణం', 'కోసం', 'రూ', '.']
#
#  Sentence 7: 300ల కోట్లు వెచ్చి ంచి భవనాన్ని నిర్మించుకొని అందులో పరిపాలన సాగించడం కాదని ప్రజాపాలన అంటే ప్రజల కష్టాలను ప్రజలకు ఎలాంటి ఇబ్బందులు రాకుండా చూడడమే పరిపాలన అని అన్నారు.
#  Tokens: ['ల', 'కోట్లు', 'వెచ్చి', 'ంచి', 'భవనాన్ని', 'నిర్మించుకొని', 'అందులో', 'పరిపాలన', 'సాగించడం', 'కాదని', 'ప్రజాపాలన', 'అంటే', 'ప్రజల', 'కష్టాలను', 'ప్రజలకు', 'ఎలాంటి', 'ఇబ్బందులు', 'రాకుండా', 'చూడడమే', 'పరిపాలన', 'అని', 'అన్నారు', '.']
#
#  Sentence 8: ఇకనైనా రాష్ట్రంలో ఖాళీ గా ఉన్న ఉద్యోగాలను భర్తీ చేయాలని ప్రభుత్వానికి సూచించారు.
#  Tokens: ['ఇకనైనా', 'రాష్ట్రంలో', 'ఖాళీ', 'గా', 'ఉన్న', 'ఉద్యోగాలను', 'భర్తీ', 'చేయాలని', 'ప్రభుత్వానికి', 'సూచించారు', '.']
#
#  Sentence 9: చేతికి వచ్చిన పిల్లలు ఆత్మహత్యలు చేసుకోవ డంతో తల్లిదండ్రులు తట్టుకోలే కపోతున్నారని ఆయన ఆవేదన వ్యక్తం చేశారు.
#  Tokens: ['చేతికి', 'వచ్చిన', 'పిల్లలు', 'ఆత్మహత్యలు', 'చేసుకోవ', 'డంతో', 'తల్లిదండ్రులు', 'తట్టుకోలే', 'కపోతున్నారని', 'ఆయన', 'ఆవేదన', 'వ్యక్తం', 'చేశారు', '.']
#
#  Sentence 10: ఆయనతో పాటు కామా రెడ్డి జడ్పిటిసి మోహన్‌రెడ్డి, కౌన్సిలర్ దామోదర్‌రెడ్డి, కామారెడ్డి కాం గ్రెస్ పార్టీ కార్యదర్శి గంగాధర్, నాయకులు తదితరులు పాల్గొన్నారు.
#  Tokens: ['ఆయనతో', 'పాటు', 'కామా', 'రెడ్డి', 'జడ్పిటిసి', 'మోహన్', 'రెడ్డి', ',', 'కౌన్సిలర్', 'దామోదర్', 'రెడ్డి', ',', 'కామారెడ్డి', 'కాం', 'గ్రెస్', 'పార్టీ', 'కార్యదర్శి', 'గంగాధర్', ',', 'నాయకులు', 'తదితరులు', 'పాల్గొన్నారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: నేను గృహ వ్యాపార ఖర్చులు తీసివేయగలనా?
#  Tokens: ['నేను', 'గృహ', 'వ్యాపార', 'ఖర్చులు', 'తీసివేయగలనా', '?']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కుషీనగర్ అంతర్జాతీయ విమానాశ్రయాన్ని ప్రధానమంత్రి నరేంద్ర మోడీ ప్రారంభించారు.
#  Tokens: ['కుషీనగర్', 'అంతర్జాతీయ', 'విమానాశ్రయాన్ని', 'ప్రధానమంత్రి', 'నరేంద్ర', 'మోడీ', 'ప్రారంభించారు', '.']
#
#  Sentence 2: అనంతరం పలు అభివృద్ధి కార్యక్రమాలకు ఆయన శ్రీకారం చుట్టారు.
#  Tokens: ['అనంతరం', 'పలు', 'అభివృద్ధి', 'కార్యక్రమాలకు', 'ఆయన', 'శ్రీకారం', 'చుట్టారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: అలాగే అప్పట్లో హీరోయిన్ గా వెలుగొందుతున్న భానుప్రియ, కుష్బూ లాంటివారికి అప్పట్లో గట్టి పోటీని ఇస్తూ వచ్చింది.
#  Tokens: ['అలాగే', 'అప్పట్లో', 'హీరోయిన్', 'గా', 'వెలుగొందుతున్న', 'భానుప్రియ', ',', 'కుష్బూ', 'లాంటివారికి', 'అప్పట్లో', 'గట్టి', 'పోటీని', 'ఇస్తూ', 'వచ్చింది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: 47ఏళ్ల చరణ్‌జిత్ సింగ్ చన్నీ..
#  Tokens: ['ఏళ్ల', 'చరణ్', 'జిత్', 'సింగ్', 'చన్నీ', '.', '.']
#
#  Sentence 2: కెప్టెన్ అమరీందర్ సింగ్ ప్రభుత్వంలో టెక్నికల్ ఎడ్యుకేషన్, ఎడ్యుకేషన్ ట్రెయినింగ్ మంత్రిత్వ శాఖకు బాధ్యత వహించారు.
#  Tokens: ['కెప్టెన్', 'అమరీందర్', 'సింగ్', 'ప్రభుత్వంలో', 'టెక్నికల్', 'ఎడ్యుకేషన్', ',', 'ఎడ్యుకేషన్', 'ట్రెయినింగ్', 'మంత్రిత్వ', 'శాఖకు', 'బాధ్యత', 'వహించారు', '.']
#
#  Sentence 3: చాంకౌర్ సాహిబ్ అసెంబ్లీ నియోజకవర్గానికి ఆయన ప్రాతినిధ్యం వహిస్తున్నారు.
#  Tokens: ['చాంకౌర్', 'సాహిబ్', 'అసెంబ్లీ', 'నియోజకవర్గానికి', 'ఆయన', 'ప్రాతినిధ్యం', 'వహిస్తున్నారు', '.']
#
#  Sentence 4: మూడు సార్లు ఎమ్మెల్యేగా గెలిచిన ఈయన రమదాసియా సిక్కు కమ్యూనిటీకి చెందినవారు.
#  Tokens: ['మూడు', 'సార్లు', 'ఎమ్మెల్యేగా', 'గెలిచిన', 'ఈయన', 'రమదాసియా', 'సిక్కు', 'కమ్యూనిటీకి', 'చెందినవారు', '.']
#
#  Sentence 5: ఈ కమ్యూనిటీ దళిత వర్గంలో భాగం.
#  Tokens: ['ఈ', 'కమ్యూనిటీ', 'దళిత', 'వర్గంలో', 'భాగం', '.']
#
#  Sentence 6: దీంతో పంజాబ్‌లో తొలి దళిత సీఎంగా చరణ్‌జిత్ సింగ్ చన్నీ నిలిచారు.
#  Tokens: ['దీంతో', 'పంజాబ్', 'లో', 'తొలి', 'దళిత', 'సీఎంగా', 'చరణ్', 'జిత్', 'సింగ్', 'చన్నీ', 'నిలిచారు', '.']
#
#  Sentence 7: కెప్టెన్‌పై తిరుగుబావుటా ఎగరేసినవారిలో చన్నీ కూడా ఉండటం గమనార్హం.
#  Tokens: ['కెప్టెన్', 'పై', 'తిరుగుబావుటా', 'ఎగరేసినవారిలో', 'చన్నీ', 'కూడా', 'ఉండటం', 'గమనార్హం', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: నందకొట్టుల ఘసిల
#  Tokens: ['నందకొట్టుల', 'ఘసిల']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: 2021 ఆరంభంలో అయినా విడుదల చేస్తారా అంటే ఇంకా ఏదో కట్టింగ్ లు చేస్తున్నట్లుగా వార్తలు వస్తున్నాయి.
#  Tokens: ['2021', 'ఆరంభంలో', 'అయినా', 'విడుదల', 'చేస్తారా', 'అంటే', 'ఇంకా', 'ఏదో', 'కట్టింగ్', 'లు', 'చేస్తున్నట్లుగా', 'వార్తలు', 'వస్తున్నాయి', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: దిల్‌రాజు బర్త్ డే పార్టీలో బెల్లంకొండ సాయి శ్రీనివాస్‌
#  Tokens: ['దిల్', 'రాజు', 'బర్త్', 'డే', 'పార్టీలో', 'బెల్లంకొండ', 'సాయి', 'శ్రీనివాస్']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తెలుగు నుంచి టాప్ గెస్ట్ అంటే ఎవరు?
#  Tokens: ['తెలుగు', 'నుంచి', 'టాప్', 'గెస్ట్', 'అంటే', 'ఎవరు', '?']
#
#  Sentence 2: మెగాస్టార్ మినహా?
#  Tokens: ['మెగాస్టార్', 'మినహా', '?']
#
#  Sentence 3: అందుకే సైమా అవార్డుల వేడుకకు ఈసారి మెగాస్టార్ చిరజీవినే చీఫ్ గెస్ట్.
#  Tokens: ['అందుకే', 'సైమా', 'అవార్డుల', 'వేడుకకు', 'ఈసారి', 'మెగాస్టార్', 'చిరజీవినే', 'చీఫ్', 'గెస్ట్', '.']
#
#  Sentence 4: ఖతర్ లో ఈ నెల 15, 16 న జరిగే సైమా అవార్డుల వేడుకకు మెగాస్టార్ చిరంజీవి చీఫ్ గెస్ట్ గా హాజరు కాబోతున్నారు.
#  Tokens: ['ఖతర్', 'లో', 'ఈ', 'నెల', '15', ',', '16', 'న', 'జరిగే', 'సైమా', 'అవార్డుల', 'వేడుకకు', 'మెగాస్టార్', 'చిరంజీవి', 'చీఫ్', 'గెస్ట్', 'గా', 'హాజరు', 'కాబోతున్నారు', '.']
#
#  Sentence 5: కేవలం తెలుగు సినిమాల సెషన్ కు మాత్రమే కాదు.
#  Tokens: ['కేవలం', 'తెలుగు', 'సినిమాల', 'సెషన్', 'కు', 'మాత్రమే', 'కాదు', '.']
#
#  Sentence 6: కన్నడ సినిమాల సెషన్ కు కూడా ఆయనే చీఫ్ గెస్ట్.
#  Tokens: ['కన్నడ', 'సినిమాల', 'సెషన్', 'కు', 'కూడా', 'ఆయనే', 'చీఫ్', 'గెస్ట్', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: పరాన్నభుక్కులకు స్వంత అస్తిత్వముండనట్టు
#  Tokens: ['పరాన్నభుక్కులకు', 'స్వంత', 'అస్తిత్వముండనట్టు']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: సినీ సెలబ్రిటీలపై పుకార్లు రావడం కామన్.
#  Tokens: ['సినీ', 'సెలబ్రిటీలపై', 'పుకార్లు', 'రావడం', 'కామన్', '.']
#
#  Sentence 2: వీటిని ఒక్కొక్కరూ ఒక్కో విధంగా హ్యాండిల్ చేస్తుంటారు.
#  Tokens: ['వీటిని', 'ఒక్కొక్కరూ', 'ఒక్కో', 'విధంగా', 'హ్యాండిల్', 'చేస్తుంటారు', '.']
#
#  Sentence 3: కొందరేమో వెంటనే రియాక్ట్ అయి తమపై వచ్చిన రూమర్స్ కి ఫుల్ స్టాప్ పెడుతుంటారు.
#  Tokens: ['కొందరేమో', 'వెంటనే', 'రియాక్ట్', 'అయి', 'తమపై', 'వచ్చిన', 'రూమర్స్', 'కి', 'ఫుల్', 'స్టాప్', 'పెడుతుంటారు', '.']
#
#  Sentence 4: కొందరు మాత్రం అసలు పట్టించుకోకుండా ఆ రూమర్స్ ను ఎంజాయ్ చేస్తుంటారు.
#  Tokens: ['కొందరు', 'మాత్రం', 'అసలు', 'పట్టించుకోకుండా', 'ఆ', 'రూమర్స్', 'ను', 'ఎంజాయ్', 'చేస్తుంటారు', '.']
#
#  Sentence 5: ఇప్పుడు సమంత కూడా ఇలానే చేస్తుంది.
#  Tokens: ['ఇప్పుడు', 'సమంత', 'కూడా', 'ఇలానే', 'చేస్తుంది', '.']
#
#  Sentence 6: ఈ మధ్యకాలంలో సమంతపై ఓ రూమర్ బాగా చక్కర్లు కొడుతోంది.
#  Tokens: ['ఈ', 'మధ్యకాలంలో', 'సమంతపై', 'ఓ', 'రూమర్', 'బాగా', 'చక్కర్లు', 'కొడుతోంది', '.']
#
#  Sentence 7: అదేంటంటే..
#  Tokens: ['అదేంటంటే', '.', '.']
#
#  Sentence 8: సామ్ కాపురం సజావుగా సాగడం లేదని..
#  Tokens: ['సామ్', 'కాపురం', 'సజావుగా', 'సాగడం', 'లేదని', '.', '.']
#
#  Sentence 9: ఆమె తన భర్త నుండి విడిపోతున్నట్లు వార్తలు వస్తున్నాయి.
# ...
#  Tokens: ['ఆ', 'ప్రమాదాన్ని', 'చూసిన', 'వాళ్లు', 'డ్రైవర్', 'బతికుండే', 'అవకాశమే', 'లేదని', 'అందరూ', 'బావించారు', '.']
#
#  Sentence 5: కాని క్షణాల వ్యవధిలో డ్రైవర్ రోమైన్ కారు నుంచి దిగి బారికేడ్లను దాటి నడుచుకుంటూ వచ్చాడు.
#  Tokens: ['కాని', 'క్షణాల', 'వ్యవధిలో', 'డ్రైవర్', 'రోమైన్', 'కారు', 'నుంచి', 'దిగి', 'బారికేడ్లను', 'దాటి', 'నడుచుకుంటూ', 'వచ్చాడు', '.']
#
#  Sentence 6: అంత ప్రమాదం నుంచి అతడు ఎలా బయటపడ్డాడని ప్రపంచమంతా చర్చించుకుంది.
#  Tokens: ['అంత', 'ప్రమాదం', 'నుంచి', 'అతడు', 'ఎలా', 'బయటపడ్డాడని', 'ప్రపంచమంతా', 'చర్చించుకుంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఆఫ్ఘనిస్తాన్‌లోని జలాలాబాద్‌ను కూడా తాలిబాన్లు స్వాధీనం చేసుకున్నారు.
#  Tokens: ['ఆఫ్ఘనిస్తాన్', 'లోని', 'జలాలాబాద్', 'ను', 'కూడా', 'తాలిబాన్లు', 'స్వాధీనం', 'చేసుకున్నారు', '.']
#
#  Sentence 2: ఆ తర్వాత కాబూల్ దేశంలోని తూర్పు ప్రాంతం నుండి తెగిపోయింది.
#  Tokens: ['ఆ', 'తర్వాత', 'కాబూల్', 'దేశంలోని', 'తూర్పు', 'ప్రాంతం', 'నుండి', 'తెగిపోయింది', '.']
#
#  Sentence 3: తాలిబాన్ ఆదివారం ఉదయం ఆన్‌లైన్‌లో కొన్ని ఫోటోలను విడుదల చేసింది.
#  Tokens: ['తాలిబాన్', 'ఆదివారం', 'ఉదయం', 'ఆన్', 'లైన్', 'లో', 'కొన్ని', 'ఫోటోలను', 'విడుదల', 'చేసింది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఊపిరితిత్తిలో ఆపరేషన్స్
#  Tokens: ['ఊపిరితిత్తిలో', 'ఆపరేషన్స్']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: పిల్లలుగా ఉన్నప్పుడు అసలు ఎలాంటి బాధలు ఉండవు.
#  Tokens: ['పిల్లలుగా', 'ఉన్నప్పుడు', 'అసలు', 'ఎలాంటి', 'బాధలు', 'ఉండవు', '.']
#
#  Sentence 2: ఆనందంగా ఎప్పుడూ నవ్వుతూ ఉంటాం.
#  Tokens: ['ఆనందంగా', 'ఎప్పుడూ', 'నవ్వుతూ', 'ఉంటాం', '.']
#
#  Sentence 3: ఈ సమయంలో ఎలాంటి బాధలు ఉండవు.
#  Tokens: ['ఈ', 'సమయంలో', 'ఎలాంటి', 'బాధలు', 'ఉండవు', '.']
#
#  Sentence 4: ఆ సమయంలో ఎప్పుడూ పెద్దగా అవుతామో అని ఆత్రంగా ఎదురుచూస్తుంటాం.
#  Tokens: ['ఆ', 'సమయంలో', 'ఎప్పుడూ', 'పెద్దగా', 'అవుతామో', 'అని', 'ఆత్రంగా', 'ఎదురుచూస్తుంటాం', '.']
#
#  Sentence 5: ఆ వయసులో ఎక్కువగా ఉత్సాహం, జాలీగా ఉంటాం.
#  Tokens: ['ఆ', 'వయసులో', 'ఎక్కువగా', 'ఉత్సాహం', ',', 'జాలీగా', 'ఉంటాం', '.']
#
#  Sentence 6: క్రమంగా పెరిగే కొద్దీ..
#  Tokens: ['క్రమంగా', 'పెరిగే', 'కొద్దీ', '.', '.']
#
#  Sentence 7: అవన్నీ ఒక్కొక్కటిగా తగ్గిపోతుంటాయి.
#  Tokens: ['అవన్నీ', 'ఒక్కొక్కటిగా', 'తగ్గిపోతుంటాయి', '.']
#
#  Sentence 8: ప్రతి విషయానికి ఇబ్బందిగా ఫీల్ అవుతుంటాం.
#  Tokens: ['ప్రతి', 'విషయానికి', 'ఇబ్బందిగా', 'ఫీల్', 'అవుతుంటాం', '.']
#
#  Sentence 9: కానీ, చిన్నపిల్లల్లో ఇవేవీ ఉండవు.
#  Tokens: ['కానీ', ',', 'చిన్నపిల్లల్లో', 'ఇవేవీ', 'ఉండవు', '.']
#
#  Sentence 10: బాధపెట్టే విషయాలను త్వరగా మరిచిపోతారు.
#  Tokens: ['బాధపెట్టే', 'విషయాలను', 'త్వరగా', 'మరిచిపోతారు', '.']
#
#  Sentence 11: ఎప్పుడూ నవ్వుతూ, ఆనందంగా గడిపేస్తారు.
#  Tokens: ['ఎప్పుడూ', 'నవ్వుతూ', ',', 'ఆనందంగా', 'గడిపేస్తారు', '.']
#
#  Sentence 12: అలా మనం ఉండడానికి ట్రై చేయాలి.
#  Tokens: ['అలా', 'మనం', 'ఉండడానికి', 'ట్రై', 'చేయాలి', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: అరోచ్‌లు (ఎద్దులు) పలు పూర్వ శిలాయుగ యూరోపియన్ గుహ పెయింటింగ్‌లలోనూ చిత్రీకరించబడ్డాయి.
#  Tokens: ['అరోచ్', 'లు', '(', 'ఎద్దులు', ')', 'పలు', 'పూర్వ', 'శిలాయుగ', 'యూరోపియన్', 'గుహ', 'పెయింటింగ్', 'లలోనూ', 'చిత్రీకరించబడ్డాయి', '.']
#
#  Sentence 2: ఇలాంటి వాటిని ఫ్రాన్స్‌లోని లాస్‌కాక్స్, లివర్‌నాన్‌లలో గుర్తించారు.
#  Tokens: ['ఇలాంటి', 'వాటిని', 'ఫ్రాన్స్', 'లోని', 'లాస్', 'కాక్స్', ',', 'లివర్', 'నాన్', 'లలో', 'గుర్తించారు', '.']
#
#  Sentence 3: వాటి జీవి శక్తికి మంత్రసంబంధమైన లక్షణాలను కలిగి ఉన్నట్లు భావించారు.
#  Tokens: ['వాటి', 'జీవి', 'శక్తికి', 'మంత్రసంబంధమైన', 'లక్షణాలను', 'కలిగి', 'ఉన్నట్లు', 'భావించారు', '.']
#
#  Sentence 4: దీనిని అరోచ్‌ల యొక్క తొలినాళ్ళ శిల్పాల విషయంలో గుర్తించారు.
#  Tokens: ['దీనిని', 'అరోచ్', 'ల', 'యొక్క', 'తొలినాళ్ళ', 'శిల్పాల', 'విషయంలో', 'గుర్తించారు', '.']
#
#  Sentence 5: ఆకర్షణీయమైన, ప్రమాదకరమైన అరోచ్‌లు అనాటోలియా, మధ్య ప్రాచ్యం ప్రాంతాల్లో ఇనుప యుగంలో మనుగడ సాగించాయి.
#  Tokens: ['ఆకర్షణీయమైన', ',', 'ప్రమాదకరమైన', 'అరోచ్', 'లు', 'అనాటోలియా', ',', 'మధ్య', 'ప్రాచ్యం', 'ప్రాంతాల్లో', 'ఇనుప', 'యుగంలో', 'మనుగడ', 'సాగించాయి', '.']
#
#  Sentence 6: ఆ ప్రాంతమంతటా వాటిని పవిత్ర జంతువులుగా పూజించారు.
#  Tokens: ['ఆ', 'ప్రాంతమంతటా', 'వాటిని', 'పవిత్ర', 'జంతువులుగా', 'పూజించారు', '.']
#
#  Sentence 7: ఎద్దులను పూజించడానికి సంబంధించిన మొదటి ఆనవాళ్లను నవీన శిలాయుగానికి చెందిన Çatalhöyük (కొత్త రాతియుగపు ప్రదేశం) వద్ద గుర్తించారు.
#  Tokens: ['ఎద్దులను', 'పూజించడానికి', 'సంబంధించిన', 'మొదటి', 'ఆనవాళ్లను', 'నవీన', 'శిలాయుగానికి', 'చెందిన', 'atalh', 'y', 'k', '(', 'కొత్త', 'రాతియుగపు', 'ప్రదేశం', ')', 'వద్ద', 'గుర్తించారు', '.']
#
#  Sentence 8: రాగి యుగం నాటికి ఈ ఎద్దులకు వృషభరాశికి సంబంధం ఏర్పడ్డట్టు గుర్తించారు, కాంస్య యుగానికి చెందిన 4000–1700 BCE కాలంలో వరదల సమయంలో వచ్చే నూతన సంవత్సరానికి ఈ వృషభం, వృషభరాశి సంకేతంగా నిలిచాయి.
#  Tokens: ['రాగి', 'యుగం', 'నాటికి', 'ఈ', 'ఎద్దులకు', 'వృషభరాశికి', 'సంబంధం', 'ఏర్పడ్డట్టు', 'గుర్తించారు', ',', 'కాంస్య', 'యుగానికి', 'చెందిన', '4000', '1700', 'BCE', 'కాలంలో', 'వరదల', 'సమయంలో', 'వచ్చే', 'నూతన', 'సంవత్సరానికి', 'ఈ', 'వృషభం', ',', 'వృషభరాశి', 'సంకేతంగా', 'నిలిచాయి', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తరవాత కథనంనర్స్ నిర్లక్ష్యం..
#  Tokens: ['తరవాత', 'కథనంనర్స్', 'నిర్లక్ష్యం', '.', '.']
#
#  Sentence 2: ఫోన్‌ మాట్లాడుకుంటూ ఓ మహిళకు రెండు కోవిడ్ టీకాలు!
#  Tokens: ['ఫోన్', 'మాట్లాడుకుంటూ', 'ఓ', 'మహిళకు', 'రెండు', 'కోవిడ్', 'టీకాలు', '!']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: News18 Telugu - IND vs SA : నేడు భారత్, సౌతాఫ్రికా మూడో టెస్టు...
#  Tokens: ['News', 'Telugu', '-', 'IND', 'vs', 'SA', ':', 'నేడు', 'భారత్', ',', 'సౌతాఫ్రికా', 'మూడో', 'టెస్టు', '.', '.', '.']
#
#  Sentence 2: వైట్‌వాషే టార్గెట్– News18 Telugu- Telugu News, Today's Latest News in Telugu IND vs SA 3rd Test : అసలే జోరుమీదున్న టీమ్ ఇండియా మ్యాచ్ చూసేందుకు ఇవాళ MS ధోనీ వస్తున్నాడు.
#  Tokens: ['వైట్', 'వాషే', 'టార్గెట్', 'News', 'Telugu', '-', 'Telugu', 'News', ',', 'Today', "'", 's', 'Latest', 'News', 'in', 'Telugu', 'IND', 'vs', 'SA', 'rd', 'Test', ':', 'అసలే', 'జోరుమీదున్న', 'టీమ్', 'ఇండియా', 'మ్యాచ్', 'చూసేందుకు', 'ఇవాళ', 'MS', 'ధోనీ', 'వస్తున్నాడు', '.']
#
#  Sentence 3: అందువల్ల కుర్రాళ్లలో ఉత్సాహం రెట్టింపైంది.
#  Tokens: ['అందువల్ల', 'కుర్రాళ్లలో', 'ఉత్సాహం', 'రెట్టింపైంది', '.']
#
#  Sentence 4: వైట్ వాష్ గ్యారెంటీ అంటున్నారు.
#  Tokens: ['వైట్', 'వాష్', 'గ్యారెంటీ', 'అంటున్నారు', '.']
#
#  Sentence 5: India vs South Africa 3rd Test : ఈ దీపావళిని విజయోత్సవాలతో జరుపుకునేందుకు టీమ్ ఇండియా రెడీ అయిపోతోంది.
#  Tokens: ['India', 'vs', 'South', 'Africa', 'rd', 'Test', ':', 'ఈ', 'దీపావళిని', 'విజయోత్సవాలతో', 'జరుపుకునేందుకు', 'టీమ్', 'ఇండియా', 'రెడీ', 'అయిపోతోంది', '.']
#
#  Sentence 6: ఇప్పటికే టెస్ట్ సిరీస్ గెలిచి చరిత్ర సృష్టించిన కోహ్లీ సేన...
#  Tokens: ['ఇప్పటికే', 'టెస్ట్', 'సిరీస్', 'గెలిచి', 'చరిత్ర', 'సృష్టించిన', 'కోహ్లీ', 'సేన', '.', '.', '.']
#
#  Sentence 7: ముచ్చటగా మూడో టెస్టు కూడా గెలిచేసి...
#  Tokens: ['ముచ్చటగా', 'మూడో', 'టెస్టు', 'కూడా', 'గెలిచేసి', '.', '.', '.']
#
#  Sentence 8: వైట్ వాష్ చెయ్యాలని టార్గెట్ పెట్టుకుంది.
#  Tokens: ['వైట్', 'వాష్', 'చెయ్యాలని', 'టార్గెట్', 'పెట్టుకుంది', '.']
#
#  Sentence 9: అందులో భాగంగా ఇవాళ జార్ఖండ్ రాజధాని రాంచీలో...
#  Tokens: ['అందులో', 'భాగంగా', 'ఇవాళ', 'జార్ఖండ్', 'రాజధాని', 'రాంచీలో', '.', '.', '.']
#
#  Sentence 10: మూడో టెస్ట్ ఉదయం 9-30 గంటలకు మొదలవ్వబోతోంది.
#  Tokens: ['మూడో', 'టెస్ట్', 'ఉదయం', '9', '-', '30', 'గంటలకు', 'మొదలవ్వబోతోంది', '.']
#
#  Sentence 11: ఈసారి స్పెషల్ ఏంటంటే...
#  Tokens: ['ఈసారి', 'స్పెషల్', 'ఏంటంటే', '.', '.', '.']
#
#  Sentence 12: జార్ఖండ్ డైనమైట్ మహేంద్రసింగ్ ధోనీ...
#  Tokens: ['జార్ఖండ్', 'డైనమైట్', 'మహేంద్రసింగ్', 'ధోనీ', '.', '.', '.']
#
#  Sentence 13: ఈ మ్యాచ్ చూసేందుకు వస్తున్నాడు.
#  Tokens: ['ఈ', 'మ్యాచ్', 'చూసేందుకు', 'వస్తున్నాడు', '.']
#
#  Sentence 14: ముంబైలో ఉన్న ధోనీ...
#  Tokens: ['ముంబైలో', 'ఉన్న', 'ధోనీ', '.', '.', '.']
#
#  Sentence 15: రాంచీ వచ్చి...
#  Tokens: ['రాంచీ', 'వచ్చి', '.', '.', '.']
#
#  Sentence 16: ఈ ఒక్క రోజూ మ్యాచ్ చూస్తాడు.
#  Tokens: ['ఈ', 'ఒక్క', 'రోజూ', 'మ్యాచ్', 'చూస్తాడు', '.']
#
#  Sentence 17: అందువల్ల అతని సూచనలు కూడా కుర్రాళ్లకు కలిసిరానున్నాయి.
#  Tokens: ['అందువల్ల', 'అతని', 'సూచనలు', 'కూడా', 'కుర్రాళ్లకు', 'కలిసిరానున్నాయి', '.']
#
#  Sentence 18: టీమిండియా లక్కేంటంటే...
#  Tokens: ['టీమిండియా', 'లక్కేంటంటే', '.', '.', '.']
#
#  Sentence 19: ప్రస్తుతం సఫారీల పరిస్థితి అస్సలు బాలేదు.
#  Tokens: ['ప్రస్తుతం', 'సఫారీల', 'పరిస్థితి', 'అస్సలు', 'బాలేదు', '.']
#
#  Sentence 20: భారత గడ్డపై వాళ్లు సరిగా ఆడలేక చతికిలపడుతున్నారు.
#  Tokens: ['భారత', 'గడ్డపై', 'వాళ్లు', 'సరిగా', 'ఆడలేక', 'చతికిలపడుతున్నారు', '.']
#
#  Sentence 21: అదే సమయంలో భారత జట్టు దుమ్ము రేపుతోంది.
#  Tokens: ['అదే', 'సమయంలో', 'భారత', 'జట్టు', 'దుమ్ము', 'రేపుతోంది', '.']
#
#  Sentence 22: ఫలితమే మొదటి టెస్టులో 203 పరుగులు, రెండో టెస్టులో మొదటి ఇన్నింగ్స్‌లో 137 పరుగుల తేడాతో టీమిండియా గెలిచింది.
#  Tokens: ['ఫలితమే', 'మొదటి', 'టెస్టులో', '203', 'పరుగులు', ',', 'రెండో', 'టెస్టులో', 'మొదటి', 'ఇన్నింగ్స్', 'లో', '137', 'పరుగుల', 'తేడాతో', 'టీమిండియా', 'గెలిచింది', '.']
#
#  Sentence 23: మరోవైపు పాయింట్ల బోర్డులో రెండో స్థానంలో ఉన్న కెప్టెన్ కోహ్లీ...
#  Tokens: ['మరోవైపు', 'పాయింట్ల', 'బోర్డులో', 'రెండో', 'స్థానంలో', 'ఉన్న', 'కెప్టెన్', 'కోహ్లీ', '.', '.', '.']
#
#  Sentence 24: ఈ టెస్టులో రాణిస్తే...
#  Tokens: ['ఈ', 'టెస్టులో', 'రాణిస్తే', '.', '.', '.']
#
#  Sentence 25: ఆస్ట్రేలియా బ్యాట్స్‌మన్, మాజీ కెప్టెన్ స్టీవ్ స్మిత్‌ని వెనక్కి నెట్టి...
#  Tokens: ['ఆస్ట్రేలియా', 'బ్యాట్స్', 'మన్', ',', 'మాజీ', 'కెప్టెన్', 'స్టీవ్', 'స్మిత్', 'ని', 'వెనక్కి', 'నెట్టి', '.', '.', '.']
#
#  Sentence 26: మొదటి స్థానాన్ని దక్కించుకునే ఛాన్స్ ఉంటుంది.
#  Tokens: ['మొదటి', 'స్థానాన్ని', 'దక్కించుకునే', 'ఛాన్స్', 'ఉంటుంది', '.']
#
#  Sentence 27: రాంచీ స్టేడియంలో ఇది రెండో టెస్ట్ మ్యాచ్ మాత్రమే.
#  Tokens: ['రాంచీ', 'స్టేడియంలో', 'ఇది', 'రెండో', 'టెస్ట్', 'మ్యాచ్', 'మాత్రమే', '.']
#
#  Sentence 28: ప్రస్తుతం పిచ్ పొడిగా ఉండటం వల్ల స్పిన్, రివర్స్ స్వింగ్‌కి ఛాన్స్ ఉందంటున్నారు.
#  Tokens: ['ప్రస్తుతం', 'పిచ్', 'పొడిగా', 'ఉండటం', 'వల్ల', 'స్పిన్', ',', 'రివర్స్', 'స్వింగ్', 'కి', 'ఛాన్స్', 'ఉందంటున్నారు', '.']
#
#  Sentence 29: ఓవరాల్‌గా బ్యాటింగ్‌కు అనుకూలమైన పిచ్.
#  Tokens: ['ఓవరాల్', 'గా', 'బ్యాటింగ్', 'కు', 'అనుకూలమైన', 'పిచ్', '.']
#
#  Sentence 30: ప్రస్తుతం ఆకాశంలో కొన్ని మేఘాలున్నా...
#  Tokens: ['ప్రస్తుతం', 'ఆకాశంలో', 'కొన్ని', 'మేఘాలున్నా', '.', '.', '.']
#
#  Sentence 31: వర్షం పడేంత సీన్ మాత్రం లేదు.
#  Tokens: ['వర్షం', 'పడేంత', 'సీన్', 'మాత్రం', 'లేదు', '.']
#
#  Sentence 32: టీమిండియా పటిష్టంగా ఉంది.
#  Tokens: ['టీమిండియా', 'పటిష్టంగా', 'ఉంది', '.']
#
#  Sentence 33: ఓపెనర్లు రోహిత్‌శర్మ, మయాంక్ అగర్వాల్‌తో పాటు చటేశ్వర్ పుజారా, కెప్టెన్ విరాట్ కోహ్లీ, వైస్ కెప్టెన్ అజింక్యా రహానే, వికెట్ కీపర్ వృద్ధిమాన్ సాహాతో బ్యాటింగ్‌లో దుమ్ము రేపుతుండగా...
#  Tokens: ['ఓపెనర్లు', 'రోహిత్', 'శర్మ', ',', 'మయాంక్', 'అగర్వాల్', 'తో', 'పాటు', 'చటేశ్వర్', 'పుజారా', ',', 'కెప్టెన్', 'విరాట్', 'కోహ్లీ', ',', 'వైస్', 'కెప్టెన్', 'అజింక్యా', 'రహానే', ',', 'వికెట్', 'కీపర్', 'వృద్ధిమాన్', 'సాహాతో', 'బ్యాటింగ్', 'లో', 'దుమ్ము', 'రేపుతుండగా', '.', '.', '.']
#
#  Sentence 34: బౌలింగ్‌లో మహ్మద్ షమీ, ఇషాంత్ శర్మ, రవీంద్ర జడేజా, రవిచంద్రన్ అశ్విన్‌ వికెట్లు పడగొట్టేందుకు సిద్ధంగా ఉన్నారు.
#  Tokens: ['బౌలింగ్', 'లో', 'మహ్మద్', 'షమీ', ',', 'ఇషాంత్', 'శర్మ', ',', 'రవీంద్ర', 'జడేజా', ',', 'రవిచంద్రన్', 'అశ్విన్', 'వికెట్లు', 'పడగొట్టేందుకు', 'సిద్ధంగా', 'ఉన్నారు', '.']
#
#  Sentence 35: భారత్‌ (అంచనా): మయాంక్‌, రోహిత్‌, పుజారా, కోహ్లీ, రహానె, జడేజా, సాహా, అశ్విన్‌, ఇషాంత్‌, ఉమేష్‌/నదీమ్‌, షమి.
#  Tokens: ['భారత్', '(', 'అంచనా', ')', ':', 'మయాంక్', ',', 'రోహిత్', ',', 'పుజారా', ',', 'కోహ్లీ', ',', 'రహానె', ',', 'జడేజా', ',', 'సాహా', ',', 'అశ్విన్', ',', 'ఇషాంత్', ',', 'ఉమేష్', '/', 'నదీమ్', ',', 'షమి', '.']
#
#  Sentence 36: దక్షిణాఫ్రికా (అంచనా) : ఎల్గర్‌, హమ్‌జా, డి బ్రుయిన్‌, డుప్లెసి, బవుమా, డికాక్‌, ముత్తుస్వామి, ఫిలాండర్‌, నోర్టే/ఎన్‌గిడి, పీట్‌, రబాడ.
#  Tokens: ['దక్షిణాఫ్రికా', '(', 'అంచనా', ')', ':', 'ఎల్గర్', ',', 'హమ్', 'జా', ',', 'డి', 'బ్రుయిన్', ',', 'డుప్లెసి', ',', 'బవుమా', ',', 'డికాక్', ',', 'ముత్తుస్వామి', ',', 'ఫిలాండర్', ',', 'నోర్టే', '/', 'ఎన్', 'గిడి', ',', 'పీట్', ',', 'రబాడ', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: మరి ఈ అంశం గురించి తన తాజా ఇంటర్వ్యూలో జేసీ స్పందించారు.
#  Tokens: ['మరి', 'ఈ', 'అంశం', 'గురించి', 'తన', 'తాజా', 'ఇంటర్వ్యూలో', 'జేసీ', 'స్పందించారు', '.']
#
#  Sentence 2: తను జగన్ ను ‘వాడు’ అనడంలో అగౌరవపరిచే ఉద్దేశం లేదని జేసీ స్పష్టం చేశారు.
#  Tokens: ['తను', 'జగన్', 'ను', '‘', 'వాడు', '’', 'అనడంలో', 'అగౌరవపరిచే', 'ఉద్దేశం', 'లేదని', 'జేసీ', 'స్పష్టం', 'చేశారు', '.']
#
#  Sentence 3: తనకు జగన్ చిన్నప్పటి నుంచి తెలుసని..
#  Tokens: ['తనకు', 'జగన్', 'చిన్నప్పటి', 'నుంచి', 'తెలుసని', '.', '.']
#
#  Sentence 4: అప్పట్లో ‘రేయ్..’అనే వాళ్లం అని, ఇప్పుడు కొత్తగా ‘సార్’ అనడం కుదురదు కదా..
#  Tokens: ['అప్పట్లో', '‘', 'రేయ్', '.', '.', '’', 'అనే', 'వాళ్లం', 'అని', ',', 'ఇప్పుడు', 'కొత్తగా', '‘', 'సార్', '’', 'అనడం', 'కుదురదు', 'కదా', '.', '.']
#
#  Sentence 5: అని జేసీ అన్నారు.
#  Tokens: ['అని', 'జేసీ', 'అన్నారు', '.']
#
#  Sentence 6: జగన్ ను ‘వాడు..’ అనడంలో వాత్సల్యమే తప్ప, జగన్ ను అగౌరవపరచాలని కాదని జేసీ చెప్పారు.
#  Tokens: ['జగన్', 'ను', '‘', 'వాడు', '.', '.', '’', 'అనడంలో', 'వాత్సల్యమే', 'తప్ప', ',', 'జగన్', 'ను', 'అగౌరవపరచాలని', 'కాదని', 'జేసీ', 'చెప్పారు', '.']
#
#  Sentence 7: తనకు పొగరు లేదని వివరణ ఇచ్చారు.
#  Tokens: ['తనకు', 'పొగరు', 'లేదని', 'వివరణ', 'ఇచ్చారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: న్యూఢిల్లీ: Indigo విమానం..
#  Tokens: ['న్యూఢిల్లీ', ':', 'Indigo', 'విమానం', '.', '.']
#
#  Sentence 2: Delhi నుంచి Mumbai కి బయల్దేరింది.
#  Tokens: ['Delhi', 'నుంచి', 'Mumbai', 'కి', 'బయల్దేరింది', '.']
#
#  Sentence 3: టేకాఫ్ అయినాక ఒక గంట తర్వాత ఓ ప్రయాణికుడు ఆరోగ్య సమస్యతో తల్లడిల్లాడు.
#  Tokens: ['టేకాఫ్', 'అయినాక', 'ఒక', 'గంట', 'తర్వాత', 'ఓ', 'ప్రయాణికుడు', 'ఆరోగ్య', 'సమస్యతో', 'తల్లడిల్లాడు', '.']
#
#  Sentence 4: ఉన్నట్టుండి తల తిప్పినట్టు అవుతున్నదని, తీవ్ర నీరసం ఆవహించిందని చెప్పాడు.
#  Tokens: ['ఉన్నట్టుండి', 'తల', 'తిప్పినట్టు', 'అవుతున్నదని', ',', 'తీవ్ర', 'నీరసం', 'ఆవహించిందని', 'చెప్పాడు', '.']
#
#  Sentence 5: Flightలో ఆకాశంలో ఉన్నది.
#  Tokens: ['Flight', 'లో', 'ఆకాశంలో', 'ఉన్నది', '.']
#
#  Sentence 6: ప్రథమ చికిత్స కిట్ ఉన్నది..
#  Tokens: ['ప్రథమ', 'చికిత్స', 'కిట్', 'ఉన్నది', '.', '.']
#
#  Sentence 7: కానీ..
#  Tokens: ['కానీ', '.', '.']
#
#  Sentence 8: వైద్యులెవరైనా ఉంటే బాగుండు అని ఫ్లైట్ సిబ్బందికి అనిపించింది.
#  Tokens: ['వైద్యులెవరైనా', 'ఉంటే', 'బాగుండు', 'అని', 'ఫ్లైట్', 'సిబ్బందికి', 'అనిపించింది', '.']
#
#  Sentence 9: తోటి ప్రయాణికుల్లో ఎవరైనా వైద్యులు ఉన్నారా?
#  Tokens: ['తోటి', 'ప్రయాణికుల్లో', 'ఎవరైనా', 'వైద్యులు', 'ఉన్నారా', '?']
#
#  Sentence 10: అని అడిగారు.
#  Tokens: ['అని', 'అడిగారు', '.']
#
#  Sentence 11: ఈ ప్రకటన వినీ వినగానే Union Minister డాక్టర్ భాగవత్ కిషన్‌రావు కరద్ ఆ పేషెంట్ దగ్గరకు పరుగన వెళ్లి ప్రథమ చికిత్స అందించాడు.
#  Tokens: ['ఈ', 'ప్రకటన', 'వినీ', 'వినగానే', 'Union', 'Minister', 'డాక్టర్', 'భాగవత్', 'కిషన్', 'రావు', 'కరద్', 'ఆ', 'పేషెంట్', 'దగ్గరకు', 'పరుగన', 'వెళ్లి', 'ప్రథమ', 'చికిత్స', 'అందించాడు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: కార్యకలాపాలకు వెళ్ళనివ్వండి.
#  Tokens: ['కార్యకలాపాలకు', 'వెళ్ళనివ్వండి', '.']
#
#  Sentence 2: కొన్నిసార్లు వారు పూర్తవుతారని మీరు అనుకోవడం లేదు ఎందుకంటే ఇది చాలా కష్టం అవుతుంది.
#  Tokens: ['కొన్నిసార్లు', 'వారు', 'పూర్తవుతారని', 'మీరు', 'అనుకోవడం', 'లేదు', 'ఎందుకంటే', 'ఇది', 'చాలా', 'కష్టం', 'అవుతుంది', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: ఆ రోజు జవహర్ లాల్ నెహ్రూ తన స్వార్థాన్ని పక్కనపెట్టి ఉంటే ఈ రోజు పాకిస్తాన్ అనే దేశం ఉండేది కాదని దలైలామా అన్నారు.
#  Tokens: ['ఆ', 'రోజు', 'జవహర్', 'లాల్', 'నెహ్రూ', 'తన', 'స్వార్థాన్ని', 'పక్కనపెట్టి', 'ఉంటే', 'ఈ', 'రోజు', 'పాకిస్తాన్', 'అనే', 'దేశం', 'ఉండేది', 'కాదని', 'దలైలామా', 'అన్నారు', '.']
#
#  Sentence 2: ఆరోజు నెహ్రూ చేసిన తప్పు వలన దేశం రెండు ముక్కలు అయ్యిందని దలైలామా వివాదాస్పద వ్యాఖ్యలు చేశారు.
#  Tokens: ['ఆరోజు', 'నెహ్రూ', 'చేసిన', 'తప్పు', 'వలన', 'దేశం', 'రెండు', 'ముక్కలు', 'అయ్యిందని', 'దలైలామా', 'వివాదాస్పద', 'వ్యాఖ్యలు', 'చేశారు', '.']
#
#  Sentence 3: దలైలామా వ్యాఖ్యలపై బీజేపీ, కాంగ్రెస్ లో భిన్నాభిప్రాయాలు వ్యక్తం అయ్యాయి.
#  Tokens: ['దలైలామా', 'వ్యాఖ్యలపై', 'బీజేపీ', ',', 'కాంగ్రెస్', 'లో', 'భిన్నాభిప్రాయాలు', 'వ్యక్తం', 'అయ్యాయి', '.']
#
#  Sentence 4: అనేక విమర్శలు రావడంతో శుక్రవారం తన వ్యాఖ్యలలో ఏమైన తప్పు ఉంటే క్షమించాలని స్వయంగా దలైలామా ప్రజలకు మనవి చేశారు.
#  Tokens: ['అనేక', 'విమర్శలు', 'రావడంతో', 'శుక్రవారం', 'తన', 'వ్యాఖ్యలలో', 'ఏమైన', 'తప్పు', 'ఉంటే', 'క్షమించాలని', 'స్వయంగా', 'దలైలామా', 'ప్రజలకు', 'మనవి', 'చేశారు', '.']
#
#  Sentence 1:
#  Tokens: []
#
#  Sentence 1: తెలంగాణలో డిసెంబర్ 7, 11 అధికారిక సెలవులు!
#  Tokens: ['తెలంగాణలో', 'డిసెంబర్', '7', ',', '11', 'అధికారిక', 'సెలవులు', '!']
#
#  Sentence 1:
#  Tokens: []

# %%
total_sentences = 0
total_words = 0
total_characters = 0
unique_tokens = set()

for i, example in enumerate(dataset):
    if i >= N:
        break

    text = example['text'].strip()
    sentences = telugu_sentence_tokenizer(text)
    total_sentences += len(sentences)

    for s in sentences:
        words = telugu_word_tokenizer(s)
        total_words += len(words)
        total_characters += sum(len(word) for word in words)
        unique_tokens.update(words)

avg_sentence_length = total_words / total_sentences if total_sentences else 0
avg_word_length = total_characters / total_words if total_words else 0
type_token_ratio = len(unique_tokens) / total_words if total_words else 0

print("\n Corpus Statistics:")
print(f"1. Total sentences       : {total_sentences}")
print(f"2. Total words           : {total_words}")
print(f"3. Total characters      : {total_characters}")
print(f"4. Avg. Sentence Length  : {avg_sentence_length:.2f} words/sentence")
print(f"5. Avg. Word Length      : {avg_word_length:.2f} chars/word")
print(f"6. Type/Token Ratio (TTR): {type_token_ratio:.4f}")
# Out:
#  Corpus Statistics:
# 1. Total sentences       : 4660
# 2. Total words           : 42381
# 3. Total characters      : 236736
# 4. Avg. Sentence Length  : 9.09 words/sentence
# 5. Avg. Word Length      : 5.59 chars/word
# 6. Type/Token Ratio (TTR): 0.3438
