# %%
import pandas as pd
import numpy as np
import random

# %%
with open("../lab4/telugu_tokenized_sentences.txt", "r", encoding="utf-8") as f:
    sentences = [line.strip() for line in f if line.strip()]  

df = pd.DataFrame(sentences, columns=["sentence"])

print(df.sample(10),"\n\n")
print("Total sentences:", len(df))
# Out:
#                                                   sentence
# 1739202                 డిగ్రీ లేని డాక్టరు ఒకరు ఉన్నారు .
# 1604528  ఇందుకోసం లక్షలాది మంది పేదల ఖాతాల్లోకి నేరుగా ...
# 339976   వారి సంప్రదాయ బద్ధంగా పూజా కార్యక్రమాలు నిర్వహ...
# 1705182  మరియు ప్రస్తుతం హోండా శాసిస్తున్న స్కూటర్ల సెగ...
# 248304   ప్రమాదానికి సంబంధించిన సమాచారం అందుకున్న అగ్ని...
# 894145   ఇది నిశ్శబ్ద ప్రాంగణంలో వచ్చిన అన్ని గతి అతివే...
# 234204           మీ ఇంటి పెద్దల ఆశీస్సులు మీకు లభిస్తాయి .
# 312750   స్వామివారిని దర్శించుకోవడానికి భక్తులు పెద్దసం...
# 1408756  అదేంటి నందమూరి బాలకృష్ణ ప్రస్తుతం చేస్తున్న 10...
# 1188681  2015 - 2023 మధ్యకాలంలో అయిదు ద్వైపాక్షిక సిరీస...
#
#
# Total sentences: 1812421

# %%
np.random.seed(42)

indices=np.random.permutation(len(df))

val_idx =indices[:1000]
test_idx=indices[1000:2000]
train_idx =indices[2000:]

val=df.iloc[val_idx]
test=df.iloc[test_idx]
train=df.iloc[train_idx]

print(len(train))
print(len(val))
print(len(test))
# Out:
# 1810421
# 1000
# 1000

# %%
train.to_csv("train_sentences.csv", index=False, encoding="utf-8")
val.to_csv("val_sentences.csv", index=False, encoding="utf-8")
test.to_csv("test_sentences.csv", index=False, encoding="utf-8")

print("Data splits saved successfully.")
# Out:
# Data splits saved successfully.
